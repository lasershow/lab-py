# %%
import pandas as pd
train_df = pd.read_csv("testdata/train.csv") #if no header, add ", header=None"
test_df = pd.read_csv("testdata/test.csv") #教師なし
combine = [train_df, test_df] # データラングリングで使う

# %%
print("Before", train_df.shape, test_df.shape, combine[0].shape, combine[1].shape)

train_df = train_df.drop(['Ticket', 'Cabin'], axis=1)
test_df = test_df.drop(['Ticket', 'Cabin'], axis=1)
combine = [train_df, test_df]

"After", train_df.shape, test_df.shape, combine[0].shape, combine[1].shape
# Out:
# Before (891, 12) (418, 11) (891, 12) (418, 11)
# ('After', (891, 10), (418, 9), (891, 10), (418, 9))

# %%
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train_df['Title'], train_df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
df = pd.read_csv("testdata/outlookcrash6Oct2017_.csv")

# %%
df.head()
# Out:
#    Level   Date and Time             Source  Event ID Task Category  \
# 0  Error  10/6/2017 8:48        EventCreate         1          None
# 1  Error  10/6/2017 8:47        EventCreate         1          None
# 2  Error  10/6/2017 8:48        EventCreate         1          None
# 3  Error  10/6/2017 8:47        EventCreate         1          None
# 4  Error  10/6/2017 8:47  Application Error      1000          -100
#
#            Log                     Computer  \
# 0  Application  djkvdihost172.jakarta01.com
# 1  Application  djkvdihost283.jakarta01.com
# 2  Application  djkvdihost570.jakarta01.com
# 3  Application  djkvdihost155.jakarta01.com
# 4  Application  djkvdihost283.jakarta01.com
#
#                                           Unnamed: 7
# 0                             JAKARTA01\Guestisd30
# 1                                 JAKARTA01\Amelia
# 2                                  JAKARTA01\ahmad
# 3                                JAKARTA01\haryadi
# 4  Faulting application name: EXCEL.EXE, version:...

# %%
df[df.iloc[:,7].str.contains("OUTLOOK.EXE")]
# Out:
#        Level    Date and Time             Source  Event ID Task Category  \
# 15     Error   10/6/2017 8:45  Application Error      1000          -100
# 21     Error   10/6/2017 8:43  Application Error      1000          -100
# 55     Error   10/6/2017 8:34  Application Error      1000          -100
# 68     Error   10/6/2017 8:32  Application Error      1000          -100
# 106    Error   10/6/2017 8:24  Application Error      1000          -100
# 109    Error   10/6/2017 8:24  Application Error      1000          -100
# 844    Error  10/5/2017 20:33  Application Error      1000          -100
# 867    Error  10/5/2017 18:31  Application Error      1000          -100
# 873    Error  10/5/2017 18:19  Application Error      1000          -100
# 876    Error  10/5/2017 18:12  Application Error      1000          -100
# 878    Error  10/5/2017 18:02  Application Error      1000          -100
# 894    Error  10/5/2017 17:34  Application Error      1000          -100
# 896    Error  10/5/2017 17:31  Application Error      1000          -100
# 899    Error  10/5/2017 17:27  Application Error      1000          -100
# 907    Error  10/5/2017 17:16  Application Error      1000          -100
# 914    Error  10/5/2017 17:12  Application Error      1000          -100
# 922    Error  10/5/2017 17:08  Application Error      1000          -100
# 928    Error  10/5/2017 17:04  Application Error      1000          -100
# 939    Error  10/5/2017 16:46  Application Error      1000          -100
# 952    Error  10/5/2017 16:34  Application Error      1000          -100
# 959    Error  10/5/2017 16:21  Application Error      1000          -100
# 975    Error  10/5/2017 16:00  Application Error      1000          -100
# 983    Error  10/5/2017 15:51  Application Error      1000          -100
# 986    Error  10/5/2017 15:50  Application Error      1000          -100
# 987    Error  10/5/2017 15:49  Application Error      1000          -100
# 989    Error  10/5/2017 15:47  Application Error      1000          -100
# 991    Error  10/5/2017 15:30  Application Error      1000          -100
# 995    Error  10/5/2017 15:19  Application Error      1000          -100
# 999    Error  10/5/2017 15:14  Application Error      1000          -100
# 1006   Error  10/5/2017 14:59  Application Error      1000          -100
# ...      ...              ...                ...       ...           ...
# 18212  Error  9/15/2017 14:02  Application Error      1000          -100
# 18221  Error  9/15/2017 13:45  Application Error      1000          -100
# 18223  Error  9/15/2017 13:44  Application Error      1000          -100
# 18232  Error  9/15/2017 13:30  Application Error      1000          -100
# 18234  Error  9/15/2017 13:28  Application Error      1000          -100
# 18240  Error  9/15/2017 12:55  Application Error      1000          -100
# 18244  Error  9/15/2017 12:30  Application Error      1000          -100
# 18246  Error  9/15/2017 12:18  Application Error      1000          -100
# 18253  Error  9/15/2017 11:44  Application Error      1000          -100
# 18268  Error  9/15/2017 11:10  Application Error      1000          -100
# 18282  Error  9/15/2017 10:45  Application Error      1000          -100
# 18284  Error  9/15/2017 10:45  Application Error      1000          -100
# 18297  Error  9/15/2017 10:32  Application Error      1000          -100
# 18300  Error  9/15/2017 10:28  Application Error      1000          -100
# 18302  Error  9/15/2017 10:28  Application Error      1000          -100
# 18309  Error  9/15/2017 10:22  Application Error      1000          -100
# 18314  Error  9/15/2017 10:15  Application Error      1000          -100
# 18322  Error   9/15/2017 9:50  Application Error      1000          -100
# 18330  Error   9/15/2017 9:42  Application Error      1000          -100
# 18335  Error   9/15/2017 9:36  Application Error      1000          -100
# 18347  Error   9/15/2017 9:25  Application Error      1000          -100
# 18358  Error   9/15/2017 9:15  Application Error      1000          -100
# 18373  Error   9/15/2017 9:11  Application Error      1000          -100
# 18405  Error   9/15/2017 8:59  Application Error      1000          -100
# 18433  Error   9/15/2017 8:54  Application Error      1000          -100
# 18481  Error   9/15/2017 8:42  Application Error      1000          -100
# 18502  Error   9/15/2017 8:33  Application Error      1000          -100
# 18533  Error   9/15/2017 8:25  Application Error      1000          -100
# 19131  Error   9/15/2017 7:20  Application Error      1000          -100
# 19153  Error   9/15/2017 7:15  Application Error      1000          -100
#
#                Log                     Computer  \
# 15     Application  djkvdihost862.jakarta01.com
# 21     Application  djkvdihost685.jakarta01.com
# 55     Application  djkvdihost008.jakarta01.com
# 68     Application  djkvdihost427.jakarta01.com
# 106    Application  djkvdihost804.jakarta01.com
# 109    Application  djkvdihost347.jakarta01.com
# 844    Application  djkvdihost120.jakarta01.com
# 867    Application  djkvdihost212.jakarta01.com
# 873    Application  djkvdihost054.jakarta01.com
# 876    Application  djkvdihost055.jakarta01.com
# 878    Application  djkvdihost160.jakarta01.com
# 894    Application  djkvdihost212.jakarta01.com
# 896    Application  djkvdihost720.jakarta01.com
# 899    Application  djkvdihost070.jakarta01.com
# 907    Application  djkvdihost498.jakarta01.com
# 914    Application  djkvdihost107.jakarta01.com
# 922    Application  djkvdihost548.jakarta01.com
# 928    Application  djkvdihost720.jakarta01.com
# 939    Application  djkvdihost898.jakarta01.com
# 952    Application  djkvdihost608.jakarta01.com
# 959    Application  djkvdihost204.jakarta01.com
# 975    Application  djkvdihost101.jakarta01.com
# 983    Application  djkvdihost745.jakarta01.com
# 986    Application  djkvdihost811.jakarta01.com
# 987    Application  djkvdihost501.jakarta01.com
# 989    Application  djkvdihost424.jakarta01.com
# 991    Application  djkvdihost817.jakarta01.com
# 995    Application  djkvdihost092.jakarta01.com
# 999    Application  djkvdihost232.jakarta01.com
# 1006   Application  djkvdihost640.jakarta01.com
# ...            ...                          ...
# 18212  Application  djkvdihost422.jakarta01.com
# 18221  Application  djkvdihost408.jakarta01.com
# 18223  Application  djkvdihost271.jakarta01.com
# 18232  Application  djkvdihost443.jakarta01.com
# 18234  Application  djkvdihost408.jakarta01.com
# 18240  Application  djkvdihost807.jakarta01.com
# 18244  Application  djkvdihost646.jakarta01.com
# 18246  Application  djkvdihost067.jakarta01.com
# 18253  Application  djkvdihost791.jakarta01.com
# 18268  Application  djkvdihost872.jakarta01.com
# 18282  Application  djkvdihost582.jakarta01.com
# 18284  Application  djkvdihost712.jakarta01.com
# 18297  Application  djkvdihost493.jakarta01.com
# 18300  Application  djkvdihost474.jakarta01.com
# 18302  Application  djkvdihost707.jakarta01.com
# 18309  Application  djkvdihost879.jakarta01.com
# 18314  Application  djkvdihost382.jakarta01.com
# 18322  Application  djkvdihost205.jakarta01.com
# 18330  Application  djkvdihost210.jakarta01.com
# 18335  Application  djkvdihost248.jakarta01.com
# 18347  Application  djkvdihost183.jakarta01.com
# 18358  Application  djkvdihost798.jakarta01.com
# 18373  Application  djkvdihost687.jakarta01.com
# 18405  Application  djkvdihost307.jakarta01.com
# 18433  Application  djkvdihost687.jakarta01.com
# 18481  Application  djkvdihost284.jakarta01.com
# 18502  Application  djkvdihost149.jakarta01.com
# 18533  Application  djkvdihost293.jakarta01.com
# 19131  Application  djkvdihost712.jakarta01.com
# 19153  Application  djkvdihost317.jakarta01.com
#
#                                               Unnamed: 7
# 15     Faulting application name: OUTLOOK.EXE, versio...
# 21     Faulting application name: OUTLOOK.EXE, versio...
# 55     Faulting application name: OUTLOOK.EXE, versio...
# 68     Faulting application name: OUTLOOK.EXE, versio...
# 106    Faulting application name: OUTLOOK.EXE, versio...
# 109    Faulting application name: OUTLOOK.EXE, versio...
# 844    Faulting application name: OUTLOOK.EXE, versio...
# 867    Faulting application name: OUTLOOK.EXE, versio...
# 873    Faulting application name: OUTLOOK.EXE, versio...
# 876    Faulting application name: OUTLOOK.EXE, versio...
# 878    Faulting application name: OUTLOOK.EXE, versio...
# 894    Faulting application name: OUTLOOK.EXE, versio...
# 896    Faulting application name: OUTLOOK.EXE, versio...
# 899    Faulting application name: OUTLOOK.EXE, versio...
# 907    Faulting application name: OUTLOOK.EXE, versio...
# 914    Faulting application name: OUTLOOK.EXE, versio...
# 922    Faulting application name: OUTLOOK.EXE, versio...
# 928    Faulting application name: OUTLOOK.EXE, versio...
# 939    Faulting application name: OUTLOOK.EXE, versio...
# 952    Faulting application name: OUTLOOK.EXE, versio...
# 959    Faulting application name: OUTLOOK.EXE, versio...
# 975    Faulting application name: OUTLOOK.EXE, versio...
# 983    Faulting application name: OUTLOOK.EXE, versio...
# 986    Faulting application name: OUTLOOK.EXE, versio...
# 987    Faulting application name: OUTLOOK.EXE, versio...
# 989    Faulting application name: OUTLOOK.EXE, versio...
# 991    Faulting application name: OUTLOOK.EXE, versio...
# 995    Faulting application name: OUTLOOK.EXE, versio...
# 999    Faulting application name: OUTLOOK.EXE, versio...
# 1006   Faulting application name: OUTLOOK.EXE, versio...
# ...                                                  ...
# 18212  Faulting application name: OUTLOOK.EXE, versio...
# 18221  Faulting application name: OUTLOOK.EXE, versio...
# 18223  Faulting application name: OUTLOOK.EXE, versio...
# 18232  Faulting application name: OUTLOOK.EXE, versio...
# 18234  Faulting application name: OUTLOOK.EXE, versio...
# 18240  Faulting application name: OUTLOOK.EXE, versio...
# 18244  Faulting application name: OUTLOOK.EXE, versio...
# 18246  Faulting application name: OUTLOOK.EXE, versio...
# 18253  Faulting application name: OUTLOOK.EXE, versio...
# 18268  Faulting application name: OUTLOOK.EXE, versio...
# 18282  Faulting application name: OUTLOOK.EXE, versio...
# 18284  Faulting application name: OUTLOOK.EXE, versio...
# 18297  Faulting application name: OUTLOOK.EXE, versio...
# 18300  Faulting application name: OUTLOOK.EXE, versio...
# 18302  Faulting application name: OUTLOOK.EXE, versio...
# 18309  Faulting application name: OUTLOOK.EXE, versio...
# 18314  Faulting application name: OUTLOOK.EXE, versio...
# 18322  Faulting application name: OUTLOOK.EXE, versio...
# 18330  Faulting application name: OUTLOOK.EXE, versio...
# 18335  Faulting application name: OUTLOOK.EXE, versio...
# 18347  Faulting application name: OUTLOOK.EXE, versio...
# 18358  Faulting application name: OUTLOOK.EXE, versio...
# 18373  Faulting application name: OUTLOOK.EXE, versio...
# 18405  Faulting application name: OUTLOOK.EXE, versio...
# 18433  Faulting application name: OUTLOOK.EXE, versio...
# 18481  Faulting application name: OUTLOOK.EXE, versio...
# 18502  Faulting application name: OUTLOOK.EXE, versio...
# 18533  Faulting application name: OUTLOOK.EXE, versio...
# 19131  Faulting application name: OUTLOOK.EXE, versio...
# 19153  Faulting application name: OUTLOOK.EXE, versio...
#
# [996 rows x 8 columns]
