# %% [markdown]
# # 課題 ボストン住宅価格 線形回帰

# %% [markdown]
# # 線形回帰とは何か
# 以下の観点をすべて含めて記述しましょう。
#
# 1. 線形回帰とは何か。
# 2. 具体的に言うと？
# 3. 分類と何か違うのか。

# %% [markdown]
# __回答：__
#
# 1. 線形回帰とは、あるデータの集合から得た複数のプロット（変数）の関係を定式化すること。y=ax+b （xが独立変数、yが従属変数）など、最適な偏回帰係数（aやb）を求める。
# 2. 最小二乗法。
# 3. 分類は与えられるカテゴリに分けること。回帰はデータの予測を行うこと。

# %% [markdown]
# # データを取得する

# %% [markdown]
# __回答：__

# %%
from sklearn.datasets import load_boston
boston = load_boston()
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # 取得データをDataFrameにする

# %%
#X=pd.DataFrame(boston.data[:100,:], columns=boston.feature_names)
#y=boston.target[:100]
# 独立変数X
X=pd.DataFrame(boston.data[:,:], columns=boston.feature_names)
# 従属変数y, XXX.targetが判定結果
Y=pd.DataFrame(boston.target[:])

# %% [markdown]
# ### チェック
# * * *

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
X['LSTAT'].isnull().any()
# Out:
# False

# %%
Y.head()
# Out:
#       0
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %% [markdown]
# * * *

# %% [markdown]
# # 説明変数を’LSTAT’のみにする

# %%
x = X['LSTAT'].values
# X['LSTAT']はSeries
# .valuesでnumpyへ

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.scatter(X['LSTAT'],Y) #同じ
##plt.scatter(x,np.array(y)) #同じ
#plt.scatter(x,y) #同じ
#plt.scatter(X['LSTAT'],y) #同じ
#plt.scatter(X,y) #Fail:全カラムを使って散布図書けない。

# %%
x.shape
# Out:
# (506,)

# %%
Y.shape
# Out:
# (506, 1)

# %% [markdown]
# # 単回帰と重回帰についての違いを記述せよ

# %% [markdown]
# __回答：__
# - 単回帰はxとしてひとつの特徴量のみを扱う回帰。
#     - 例）身長と体重の関係。x:身長,y:体重
# - 重回帰は複数のxとして、複数の特徴量を扱う回帰。
#     - 例）新幹線の利用者。x1:GDP成長率、x2：高速道路の通行料、x3：航空運賃,y:新幹線の利用者数

# %% [markdown]
# # テストデータに分割する

# %% [markdown]
# <font color="red">__※X and y??__</font>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %% [markdown]
# ### ※データの形状を確認する
# * * *

# %%
X_test.shape
# Out:
# (102, 13)

# %%
X_train.shape
# Out:
# (404, 13)

# %%
y_test.shape
# Out:
# (102, 1)

# %%
y_test.head() # Seriesは行列？
# Out:
#         0
# 329  22.6
# 371  50.0
# 219  23.0
# 403   8.3
# 78   21.2

# %%
type(y_test)
# Out:
# pandas.core.frame.DataFrame

# %%
y_test.ndim
# Out:
# 2

# %%
y_train.shape
# Out:
# (404, 1)

# %%
plt.scatter(X_train['LSTAT'],y_train)
# 母集団の似た散布図

# %% [markdown]
# * * *

# %% [markdown]
# # 学習
# <font color="red">__※やり方がただしいか？ fitの引数はDF?またはnumpy?__</font>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
lin_1d = LinearRegression()

# %%
X_train.shape
# Out:
# (404, 13)

# %%
y_train.shape
# Out:
# (404, 1)

# %%
#x = X_train["LSTAT"].values
x = X_train.loc[:, ['LSTAT']].as_matrix() #でもOK

lin_1d.fit(x, y_train) #OK
#lin_1d.fit(x[:,np.newaxis], Y_train) #OK
#lin_1d.fit(x[:,np.newaxis], np.array(Y_train)) #OK
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(type(x))
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.frame.DataFrame'>

# %%
lin_1d.predict(25)
# Out:
# array([[ 10.85300242]])

# %%
#まずプロット用のデータを用意します。
n = np.linspace(np.min(x),np.max(x), 1000)
y_1d_fit=lin_1d.predict(n[:,np.newaxis])

plt.scatter(x,y_train,label='data')
plt.plot(n,y_1d_fit,'r',label='1d_lin')
plt.ylim(10,40)#グラフを見やすくするためにｙ軸のプロット範囲を絞っているだけです。
plt.xlabel("LSTAT")
plt.ylabel("price")
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# <font color="red">※2乗誤差正しい？</font>

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_train, lin_1d.predict(x))
# Out:
# 36.523966406959666

# %% [markdown]
# # 決定係数

# %%
x_test = X_test['LSTAT'].values[:,np.newaxis]
score_1d = lin_1d.score(x_test, y_test)
print("一次式における'LSTAT'の住宅価格への決定係数は%.2f" % (score_1d))
# Out:
# 一次式における'LSTAT'の住宅価格への決定係数は0.43

# %% [markdown]
# # 決定係数とは何か記述せよ

# %% [markdown]
# 1. 決定係数とは何か
# 2. もっとも説明変数が、目的変数を説明できる場合、決定係数は何になるか
# 3. どのように求めることができるか

# %% [markdown]
# __回答：__
# 1. 推定した回帰式がどの程度の説明力を有するかを示す指標。当てはまり具合を表す。
# 2. もっとも説明変数が、目的変数を説明できる場合、決定係数は1になる。
# 3. 実際のデータと推定された回帰式から「全変動」「回帰変動」「残差変動」の3つを求め、以下の式に当てはめる。
#
# 「全変動」＝「回帰変動」＋「残差変動」
# つまり「回帰変動が全変動に対してどれだけ多いか＝残差変動が全変動に対してどれだけ少ないか」を表す。
# したがって決定係数は、下記のように回帰変動を全変動で割ることで求められます。
#
# R^2 = 回帰変動 / 全変動
#
# これは下記の式と同じ。
#
# R^2 = 1 - （残差変動 / 全変動）
#
# なので決定係数は0から1の範囲内となる。
# [参考](https://bellcurve.jp/statistics/course/9706.html)

# %% [markdown]
# # 決定係数をいかなる場合も信じても良いか記述せよ(決定係数が高ければ、汎用性があるモデルと言えるか)

# %% [markdown]
# 信じるべきではない。
#
# - 決定係数は標本から求めた回帰方程式の当てはまり具合。母集団を意識して自由度を加味した自由度調整済み決定係数のほうが正確。
# - ただ次の理由で自由度調整済み決定係数も信じるべきではない。（引用）目的や仮説とは一切関係ない変数を、決定係数が上がるからという理由だけで無秩序に分析に加えてしまうと、そのモデルは解釈が難しくなり当初の目的を果たせない。外れ値を含む場合も同様に決定係数に影響を与える。
# - 使い方には注意。決定係数はあくまで「予測の当てはまりの良さ」を表す指標。分析の目的が「ある変数の値を予測」であること。ある変数の影響の有無が主眼であり予測は重視しない場合には適さない。[参考](http://xica.net/magellan/marketing-idea/stats/about-coefficient-of-determination/)

# %% [markdown]
# # 2,3,4次式の回帰

# %% [markdown]
# #### degree1

# %%
x_test = X_test['LSTAT'].values[:,np.newaxis]
score_1d = lin_1d.score(x_test, y_test)
print("一次式における'LSTAT'の住宅価格への決定係数は%.2f" % (score_1d))
# Out:
# 一次式における'LSTAT'の住宅価格への決定係数は0.43

# %%
mean_squared_error(y_train, lin_1d.predict(x))
# Out:
# 36.523966406959666

# %% [markdown]
# * * *
# #### degree2

# %% [markdown]
# ##### calculation

# %%
degree_2=PolynomialFeatures(degree=2)
x_train = X_train.loc[:, ['LSTAT']].as_matrix()
x_train_2=degree_2.fit_transform(x_train)

# %%
lin_2d = LinearRegression()
lin_2d.fit(x_train_2, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
x_test = X_test.loc[:, ['LSTAT']].as_matrix()

# %%
x_test_2 = degree_2.fit_transform(x_test)

# %% [markdown]
# ##### 決定係数

# %%
lin_2d.score(x_test_2, y_test)
# Out:
# 0.52293241637387822

# %% [markdown]
# ##### 誤差関数

# %%
mean_squared_error(y_test,lin_2d.predict(x_test_2))
# Out:
# 38.846868661707191

# %% [markdown]
# * * *
# #### degree3,4,5

# %% [markdown]
# ##### calculation

# %%
degree_3=PolynomialFeatures(degree=3)
degree_4=PolynomialFeatures(degree=4)
degree_5=PolynomialFeatures(degree=5)
x_train = X_train.loc[:, ['LSTAT']].as_matrix()
x_train_3=degree_3.fit_transform(x_train)
x_train_4=degree_4.fit_transform(x_train)
x_train_5=degree_5.fit_transform(x_train)

# %%
lin_3d = LinearRegression()
lin_4d = LinearRegression()
lin_5d = LinearRegression()

lin_3d.fit(x_train_3, y_train)
lin_4d.fit(x_train_4, y_train)
lin_5d.fit(x_train_5, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
x_test = X_test.loc[:, ['LSTAT']].as_matrix()

# %%
x_test_3 = degree_3.fit_transform(x_test)
x_test_4 = degree_4.fit_transform(x_test)
x_test_5 = degree_5.fit_transform(x_test)

# %% [markdown]
# ##### 決定係数

# %%
print("degree 3: %f" % lin_3d.score(x_test_3, y_test))
print("degree 4: %f" % lin_4d.score(x_test_4, y_test))
print("degree 5: %f" % lin_5d.score(x_test_5, y_test))
# Out:
# degree 3: 0.542859
# degree 4: 0.573799
# degree 5: 0.572205

# %% [markdown]
# ##### 誤差関数

# %%
print("degree 3: %f" % mean_squared_error(y_test,lin_3d.predict(x_test_3)))
print("degree 4: %f" % mean_squared_error(y_test,lin_4d.predict(x_test_4)))
print("degree 5: %f" % mean_squared_error(y_test,lin_5d.predict(x_test_5)))
# Out:
# degree 3: 37.224242
# degree 4: 34.704869
# degree 5: 34.834708

# %% [markdown]
# * * * * *

# %% [markdown]
# # 次数が大きくなるとどうなるか記述せよ
# - 説明変数をxとして、次数を増やしていくとどのように数式が変化していくか記述せよ（1次式 ax + b）
# - 次数を増やすとどのようなメリットが考えられるか
# - 次数を増やすとどのようなデメリットが考えられるか

# %% [markdown]
# __回答：__
# - ax^2+bx+1,
# - 表現力が高くなる
# - 過学習しやすくなる

# %% [markdown]
# * * * *
# # 重回帰

# %% [markdown]
# #### 単回帰

# %%
# LSTAT
x_test = X_test['LSTAT'].values[:,np.newaxis]
score_1d = lin_1d.score(x_test, y_test)
print("一次式における'LSTAT'の住宅価格への決定係数は%f" % (score_1d))
# Out:
# 一次式における'LSTAT'の住宅価格への決定係数は0.430957

# %% [markdown]
# #### 重回帰

# %%
lin_1d_2 = LinearRegression()

# 説明変数に前回と同じLSTATを使ってみましょう。今回は前回とは違う風にnumpyにデータを変換していれてみましょう。
x2 = X_train.loc[:, ['LSTAT','CRIM']].as_matrix()
# このままでもscikit learnのモデルを使うことができます。
lin_1d_2.fit(x2, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#汎化能力を見るため、テストデータを使って最小誤差を計算します。
x2_test = X_test.loc[:, ['LSTAT','CRIM']].as_matrix()

# %%
score_1d_2 = lin_1d_2.score(x2_test, y_test)
print("一次式における'LSTAT','CRIM'の住宅価格への決定係数は%f" % (score_1d_2))
# Out:
# 一次式における'LSTAT','CRIM'の住宅価格への決定係数は0.428749

# %% [markdown]
# #### for文確認

# %%
from itertools import chain, combinations
i = set(list(X.columns))
for p in chain.from_iterable(combinations(i, r) for r in range(len(i)+1)):
    print(p)
# Out:
# ()
# ('LSTAT',)
# ('INDUS',)
# ('CRIM',)
# ('PTRATIO',)
# ('B',)
# ('CHAS',)
# ('DIS',)
# ('NOX',)
# ('RAD',)
# ('RM',)
# ('TAX',)
# ('AGE',)
# ('ZN',)
# ('LSTAT', 'INDUS')
# ('LSTAT', 'CRIM')
# ('LSTAT', 'PTRATIO')
# ('LSTAT', 'B')
# ('LSTAT', 'CHAS')
# ('LSTAT', 'DIS')
# ('LSTAT', 'NOX')
# ('LSTAT', 'RAD')
# ('LSTAT', 'RM')
# ('LSTAT', 'TAX')
# ('LSTAT', 'AGE')
# ('LSTAT', 'ZN')
# ('INDUS', 'CRIM')
# ('INDUS', 'PTRATIO')
# ('INDUS', 'B')
# ('INDUS', 'CHAS')
# ('INDUS', 'DIS')
# ('INDUS', 'NOX')
# ('INDUS', 'RAD')
# ('INDUS', 'RM')
# ('INDUS', 'TAX')
# ('INDUS', 'AGE')
# ('INDUS', 'ZN')
# ('CRIM', 'PTRATIO')
# ('CRIM', 'B')
# ('CRIM', 'CHAS')
# ('CRIM', 'DIS')
# ('CRIM', 'NOX')
# ('CRIM', 'RAD')
# ('CRIM', 'RM')
# ('CRIM', 'TAX')
# ('CRIM', 'AGE')
# ('CRIM', 'ZN')
# ('PTRATIO', 'B')
# ('PTRATIO', 'CHAS')
# ('PTRATIO', 'DIS')
# ('PTRATIO', 'NOX')
# ('PTRATIO', 'RAD')
# ('PTRATIO', 'RM')
# ('PTRATIO', 'TAX')
# ('PTRATIO', 'AGE')
# ('PTRATIO', 'ZN')
# ('B', 'CHAS')
# ('B', 'DIS')
# ('B', 'NOX')
# ('B', 'RAD')
# ('B', 'RM')
# ('B', 'TAX')
# ('B', 'AGE')
# ('B', 'ZN')
# ('CHAS', 'DIS')
# ('CHAS', 'NOX')
# ('CHAS', 'RAD')
# ('CHAS', 'RM')
# ('CHAS', 'TAX')
# ('CHAS', 'AGE')
# ('CHAS', 'ZN')
# ('DIS', 'NOX')
# ('DIS', 'RAD')
# ('DIS', 'RM')
# ('DIS', 'TAX')
# ('DIS', 'AGE')
# ('DIS', 'ZN')
# ('NOX', 'RAD')
# ('NOX', 'RM')
# ('NOX', 'TAX')
# ('NOX', 'AGE')
# ('NOX', 'ZN')
# ('RAD', 'RM')
# ('RAD', 'TAX')
# ('RAD', 'AGE')
# ('RAD', 'ZN')
# ('RM', 'TAX')
# ('RM', 'AGE')
# ('RM', 'ZN')
# ('TAX', 'AGE')
# ('TAX', 'ZN')
# ('AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM')
# ('LSTAT', 'INDUS', 'PTRATIO')
# ('LSTAT', 'INDUS', 'B')
# ('LSTAT', 'INDUS', 'CHAS')
# ('LSTAT', 'INDUS', 'DIS')
# ('LSTAT', 'INDUS', 'NOX')
# ('LSTAT', 'INDUS', 'RAD')
# ('LSTAT', 'INDUS', 'RM')
# ('LSTAT', 'INDUS', 'TAX')
# ('LSTAT', 'INDUS', 'AGE')
# ('LSTAT', 'INDUS', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO')
# ('LSTAT', 'CRIM', 'B')
# ('LSTAT', 'CRIM', 'CHAS')
# ('LSTAT', 'CRIM', 'DIS')
# ('LSTAT', 'CRIM', 'NOX')
# ('LSTAT', 'CRIM', 'RAD')
# ('LSTAT', 'CRIM', 'RM')
# ('LSTAT', 'CRIM', 'TAX')
# ('LSTAT', 'CRIM', 'AGE')
# ('LSTAT', 'CRIM', 'ZN')
# ('LSTAT', 'PTRATIO', 'B')
# ('LSTAT', 'PTRATIO', 'CHAS')
# ('LSTAT', 'PTRATIO', 'DIS')
# ('LSTAT', 'PTRATIO', 'NOX')
# ('LSTAT', 'PTRATIO', 'RAD')
# ('LSTAT', 'PTRATIO', 'RM')
# ('LSTAT', 'PTRATIO', 'TAX')
# ('LSTAT', 'PTRATIO', 'AGE')
# ('LSTAT', 'PTRATIO', 'ZN')
# ('LSTAT', 'B', 'CHAS')
# ('LSTAT', 'B', 'DIS')
# ('LSTAT', 'B', 'NOX')
# ('LSTAT', 'B', 'RAD')
# ('LSTAT', 'B', 'RM')
# ('LSTAT', 'B', 'TAX')
# ('LSTAT', 'B', 'AGE')
# ('LSTAT', 'B', 'ZN')
# ('LSTAT', 'CHAS', 'DIS')
# ('LSTAT', 'CHAS', 'NOX')
# ('LSTAT', 'CHAS', 'RAD')
# ('LSTAT', 'CHAS', 'RM')
# ('LSTAT', 'CHAS', 'TAX')
# ('LSTAT', 'CHAS', 'AGE')
# ('LSTAT', 'CHAS', 'ZN')
# ('LSTAT', 'DIS', 'NOX')
# ('LSTAT', 'DIS', 'RAD')
# ('LSTAT', 'DIS', 'RM')
# ('LSTAT', 'DIS', 'TAX')
# ('LSTAT', 'DIS', 'AGE')
# ('LSTAT', 'DIS', 'ZN')
# ('LSTAT', 'NOX', 'RAD')
# ('LSTAT', 'NOX', 'RM')
# ('LSTAT', 'NOX', 'TAX')
# ('LSTAT', 'NOX', 'AGE')
# ('LSTAT', 'NOX', 'ZN')
# ('LSTAT', 'RAD', 'RM')
# ('LSTAT', 'RAD', 'TAX')
# ('LSTAT', 'RAD', 'AGE')
# ('LSTAT', 'RAD', 'ZN')
# ('LSTAT', 'RM', 'TAX')
# ('LSTAT', 'RM', 'AGE')
# ('LSTAT', 'RM', 'ZN')
# ('LSTAT', 'TAX', 'AGE')
# ('LSTAT', 'TAX', 'ZN')
# ('LSTAT', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO')
# ('INDUS', 'CRIM', 'B')
# ('INDUS', 'CRIM', 'CHAS')
# ('INDUS', 'CRIM', 'DIS')
# ('INDUS', 'CRIM', 'NOX')
# ('INDUS', 'CRIM', 'RAD')
# ('INDUS', 'CRIM', 'RM')
# ('INDUS', 'CRIM', 'TAX')
# ('INDUS', 'CRIM', 'AGE')
# ('INDUS', 'CRIM', 'ZN')
# ('INDUS', 'PTRATIO', 'B')
# ('INDUS', 'PTRATIO', 'CHAS')
# ('INDUS', 'PTRATIO', 'DIS')
# ('INDUS', 'PTRATIO', 'NOX')
# ('INDUS', 'PTRATIO', 'RAD')
# ('INDUS', 'PTRATIO', 'RM')
# ('INDUS', 'PTRATIO', 'TAX')
# ('INDUS', 'PTRATIO', 'AGE')
# ('INDUS', 'PTRATIO', 'ZN')
# ('INDUS', 'B', 'CHAS')
# ('INDUS', 'B', 'DIS')
# ('INDUS', 'B', 'NOX')
# ('INDUS', 'B', 'RAD')
# ('INDUS', 'B', 'RM')
# ('INDUS', 'B', 'TAX')
# ('INDUS', 'B', 'AGE')
# ('INDUS', 'B', 'ZN')
# ('INDUS', 'CHAS', 'DIS')
# ('INDUS', 'CHAS', 'NOX')
# ('INDUS', 'CHAS', 'RAD')
# ('INDUS', 'CHAS', 'RM')
# ('INDUS', 'CHAS', 'TAX')
# ('INDUS', 'CHAS', 'AGE')
# ('INDUS', 'CHAS', 'ZN')
# ('INDUS', 'DIS', 'NOX')
# ('INDUS', 'DIS', 'RAD')
# ('INDUS', 'DIS', 'RM')
# ('INDUS', 'DIS', 'TAX')
# ('INDUS', 'DIS', 'AGE')
# ('INDUS', 'DIS', 'ZN')
# ('INDUS', 'NOX', 'RAD')
# ('INDUS', 'NOX', 'RM')
# ('INDUS', 'NOX', 'TAX')
# ('INDUS', 'NOX', 'AGE')
# ('INDUS', 'NOX', 'ZN')
# ('INDUS', 'RAD', 'RM')
# ('INDUS', 'RAD', 'TAX')
# ('INDUS', 'RAD', 'AGE')
# ('INDUS', 'RAD', 'ZN')
# ('INDUS', 'RM', 'TAX')
# ('INDUS', 'RM', 'AGE')
# ('INDUS', 'RM', 'ZN')
# ('INDUS', 'TAX', 'AGE')
# ('INDUS', 'TAX', 'ZN')
# ('INDUS', 'AGE', 'ZN')
# ('CRIM', 'PTRATIO', 'B')
# ('CRIM', 'PTRATIO', 'CHAS')
# ('CRIM', 'PTRATIO', 'DIS')
# ('CRIM', 'PTRATIO', 'NOX')
# ('CRIM', 'PTRATIO', 'RAD')
# ('CRIM', 'PTRATIO', 'RM')
# ('CRIM', 'PTRATIO', 'TAX')
# ('CRIM', 'PTRATIO', 'AGE')
# ('CRIM', 'PTRATIO', 'ZN')
# ('CRIM', 'B', 'CHAS')
# ('CRIM', 'B', 'DIS')
# ('CRIM', 'B', 'NOX')
# ('CRIM', 'B', 'RAD')
# ('CRIM', 'B', 'RM')
# ('CRIM', 'B', 'TAX')
# ('CRIM', 'B', 'AGE')
# ('CRIM', 'B', 'ZN')
# ('CRIM', 'CHAS', 'DIS')
# ('CRIM', 'CHAS', 'NOX')
# ('CRIM', 'CHAS', 'RAD')
# ('CRIM', 'CHAS', 'RM')
# ('CRIM', 'CHAS', 'TAX')
# ('CRIM', 'CHAS', 'AGE')
# ('CRIM', 'CHAS', 'ZN')
# ('CRIM', 'DIS', 'NOX')
# ('CRIM', 'DIS', 'RAD')
# ('CRIM', 'DIS', 'RM')
# ('CRIM', 'DIS', 'TAX')
# ('CRIM', 'DIS', 'AGE')
# ('CRIM', 'DIS', 'ZN')
# ('CRIM', 'NOX', 'RAD')
# ('CRIM', 'NOX', 'RM')
# ('CRIM', 'NOX', 'TAX')
# ('CRIM', 'NOX', 'AGE')
# ('CRIM', 'NOX', 'ZN')
# ('CRIM', 'RAD', 'RM')
# ('CRIM', 'RAD', 'TAX')
# ('CRIM', 'RAD', 'AGE')
# ('CRIM', 'RAD', 'ZN')
# ('CRIM', 'RM', 'TAX')
# ('CRIM', 'RM', 'AGE')
# ('CRIM', 'RM', 'ZN')
# ('CRIM', 'TAX', 'AGE')
# ('CRIM', 'TAX', 'ZN')
# ('CRIM', 'AGE', 'ZN')
# ('PTRATIO', 'B', 'CHAS')
# ('PTRATIO', 'B', 'DIS')
# ('PTRATIO', 'B', 'NOX')
# ('PTRATIO', 'B', 'RAD')
# ('PTRATIO', 'B', 'RM')
# ('PTRATIO', 'B', 'TAX')
# ('PTRATIO', 'B', 'AGE')
# ('PTRATIO', 'B', 'ZN')
# ('PTRATIO', 'CHAS', 'DIS')
# ('PTRATIO', 'CHAS', 'NOX')
# ('PTRATIO', 'CHAS', 'RAD')
# ('PTRATIO', 'CHAS', 'RM')
# ('PTRATIO', 'CHAS', 'TAX')
# ('PTRATIO', 'CHAS', 'AGE')
# ('PTRATIO', 'CHAS', 'ZN')
# ('PTRATIO', 'DIS', 'NOX')
# ('PTRATIO', 'DIS', 'RAD')
# ('PTRATIO', 'DIS', 'RM')
# ('PTRATIO', 'DIS', 'TAX')
# ('PTRATIO', 'DIS', 'AGE')
# ('PTRATIO', 'DIS', 'ZN')
# ('PTRATIO', 'NOX', 'RAD')
# ('PTRATIO', 'NOX', 'RM')
# ('PTRATIO', 'NOX', 'TAX')
# ('PTRATIO', 'NOX', 'AGE')
# ('PTRATIO', 'NOX', 'ZN')
# ('PTRATIO', 'RAD', 'RM')
# ('PTRATIO', 'RAD', 'TAX')
# ('PTRATIO', 'RAD', 'AGE')
# ('PTRATIO', 'RAD', 'ZN')
# ('PTRATIO', 'RM', 'TAX')
# ('PTRATIO', 'RM', 'AGE')
# ('PTRATIO', 'RM', 'ZN')
# ('PTRATIO', 'TAX', 'AGE')
# ('PTRATIO', 'TAX', 'ZN')
# ('PTRATIO', 'AGE', 'ZN')
# ('B', 'CHAS', 'DIS')
# ('B', 'CHAS', 'NOX')
# ('B', 'CHAS', 'RAD')
# ('B', 'CHAS', 'RM')
# ('B', 'CHAS', 'TAX')
# ('B', 'CHAS', 'AGE')
# ('B', 'CHAS', 'ZN')
# ('B', 'DIS', 'NOX')
# ('B', 'DIS', 'RAD')
# ('B', 'DIS', 'RM')
# ('B', 'DIS', 'TAX')
# ('B', 'DIS', 'AGE')
# ('B', 'DIS', 'ZN')
# ('B', 'NOX', 'RAD')
# ('B', 'NOX', 'RM')
# ('B', 'NOX', 'TAX')
# ('B', 'NOX', 'AGE')
# ('B', 'NOX', 'ZN')
# ('B', 'RAD', 'RM')
# ('B', 'RAD', 'TAX')
# ('B', 'RAD', 'AGE')
# ('B', 'RAD', 'ZN')
# ('B', 'RM', 'TAX')
# ('B', 'RM', 'AGE')
# ('B', 'RM', 'ZN')
# ('B', 'TAX', 'AGE')
# ('B', 'TAX', 'ZN')
# ('B', 'AGE', 'ZN')
# ('CHAS', 'DIS', 'NOX')
# ('CHAS', 'DIS', 'RAD')
# ('CHAS', 'DIS', 'RM')
# ('CHAS', 'DIS', 'TAX')
# ('CHAS', 'DIS', 'AGE')
# ('CHAS', 'DIS', 'ZN')
# ('CHAS', 'NOX', 'RAD')
# ('CHAS', 'NOX', 'RM')
# ('CHAS', 'NOX', 'TAX')
# ('CHAS', 'NOX', 'AGE')
# ('CHAS', 'NOX', 'ZN')
# ('CHAS', 'RAD', 'RM')
# ('CHAS', 'RAD', 'TAX')
# ('CHAS', 'RAD', 'AGE')
# ('CHAS', 'RAD', 'ZN')
# ('CHAS', 'RM', 'TAX')
# ('CHAS', 'RM', 'AGE')
# ('CHAS', 'RM', 'ZN')
# ('CHAS', 'TAX', 'AGE')
# ('CHAS', 'TAX', 'ZN')
# ('CHAS', 'AGE', 'ZN')
# ('DIS', 'NOX', 'RAD')
# ('DIS', 'NOX', 'RM')
# ('DIS', 'NOX', 'TAX')
# ('DIS', 'NOX', 'AGE')
# ('DIS', 'NOX', 'ZN')
# ('DIS', 'RAD', 'RM')
# ('DIS', 'RAD', 'TAX')
# ('DIS', 'RAD', 'AGE')
# ('DIS', 'RAD', 'ZN')
# ('DIS', 'RM', 'TAX')
# ('DIS', 'RM', 'AGE')
# ('DIS', 'RM', 'ZN')
# ('DIS', 'TAX', 'AGE')
# ('DIS', 'TAX', 'ZN')
# ('DIS', 'AGE', 'ZN')
# ('NOX', 'RAD', 'RM')
# ('NOX', 'RAD', 'TAX')
# ('NOX', 'RAD', 'AGE')
# ('NOX', 'RAD', 'ZN')
# ('NOX', 'RM', 'TAX')
# ('NOX', 'RM', 'AGE')
# ('NOX', 'RM', 'ZN')
# ('NOX', 'TAX', 'AGE')
# ('NOX', 'TAX', 'ZN')
# ('NOX', 'AGE', 'ZN')
# ('RAD', 'RM', 'TAX')
# ('RAD', 'RM', 'AGE')
# ('RAD', 'RM', 'ZN')
# ('RAD', 'TAX', 'AGE')
# ('RAD', 'TAX', 'ZN')
# ('RAD', 'AGE', 'ZN')
# ('RM', 'TAX', 'AGE')
# ('RM', 'TAX', 'ZN')
# ('RM', 'AGE', 'ZN')
# ('TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO')
# ('LSTAT', 'INDUS', 'CRIM', 'B')
# ('LSTAT', 'INDUS', 'CRIM', 'CHAS')
# ('LSTAT', 'INDUS', 'CRIM', 'DIS')
# ('LSTAT', 'INDUS', 'CRIM', 'NOX')
# ('LSTAT', 'INDUS', 'CRIM', 'RAD')
# ('LSTAT', 'INDUS', 'CRIM', 'RM')
# ('LSTAT', 'INDUS', 'CRIM', 'TAX')
# ('LSTAT', 'INDUS', 'CRIM', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B')
# ('LSTAT', 'INDUS', 'PTRATIO', 'CHAS')
# ('LSTAT', 'INDUS', 'PTRATIO', 'DIS')
# ('LSTAT', 'INDUS', 'PTRATIO', 'NOX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'RAD')
# ('LSTAT', 'INDUS', 'PTRATIO', 'RM')
# ('LSTAT', 'INDUS', 'PTRATIO', 'TAX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'AGE')
# ('LSTAT', 'INDUS', 'PTRATIO', 'ZN')
# ('LSTAT', 'INDUS', 'B', 'CHAS')
# ('LSTAT', 'INDUS', 'B', 'DIS')
# ('LSTAT', 'INDUS', 'B', 'NOX')
# ('LSTAT', 'INDUS', 'B', 'RAD')
# ('LSTAT', 'INDUS', 'B', 'RM')
# ('LSTAT', 'INDUS', 'B', 'TAX')
# ('LSTAT', 'INDUS', 'B', 'AGE')
# ('LSTAT', 'INDUS', 'B', 'ZN')
# ('LSTAT', 'INDUS', 'CHAS', 'DIS')
# ('LSTAT', 'INDUS', 'CHAS', 'NOX')
# ('LSTAT', 'INDUS', 'CHAS', 'RAD')
# ('LSTAT', 'INDUS', 'CHAS', 'RM')
# ('LSTAT', 'INDUS', 'CHAS', 'TAX')
# ('LSTAT', 'INDUS', 'CHAS', 'AGE')
# ('LSTAT', 'INDUS', 'CHAS', 'ZN')
# ('LSTAT', 'INDUS', 'DIS', 'NOX')
# ('LSTAT', 'INDUS', 'DIS', 'RAD')
# ('LSTAT', 'INDUS', 'DIS', 'RM')
# ('LSTAT', 'INDUS', 'DIS', 'TAX')
# ('LSTAT', 'INDUS', 'DIS', 'AGE')
# ('LSTAT', 'INDUS', 'DIS', 'ZN')
# ('LSTAT', 'INDUS', 'NOX', 'RAD')
# ('LSTAT', 'INDUS', 'NOX', 'RM')
# ('LSTAT', 'INDUS', 'NOX', 'TAX')
# ('LSTAT', 'INDUS', 'NOX', 'AGE')
# ('LSTAT', 'INDUS', 'NOX', 'ZN')
# ('LSTAT', 'INDUS', 'RAD', 'RM')
# ('LSTAT', 'INDUS', 'RAD', 'TAX')
# ('LSTAT', 'INDUS', 'RAD', 'AGE')
# ('LSTAT', 'INDUS', 'RAD', 'ZN')
# ('LSTAT', 'INDUS', 'RM', 'TAX')
# ('LSTAT', 'INDUS', 'RM', 'AGE')
# ('LSTAT', 'INDUS', 'RM', 'ZN')
# ('LSTAT', 'INDUS', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS')
# ('LSTAT', 'CRIM', 'PTRATIO', 'DIS')
# ('LSTAT', 'CRIM', 'PTRATIO', 'NOX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'RAD')
# ('LSTAT', 'CRIM', 'PTRATIO', 'RM')
# ('LSTAT', 'CRIM', 'PTRATIO', 'TAX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'CHAS')
# ('LSTAT', 'CRIM', 'B', 'DIS')
# ('LSTAT', 'CRIM', 'B', 'NOX')
# ('LSTAT', 'CRIM', 'B', 'RAD')
# ('LSTAT', 'CRIM', 'B', 'RM')
# ('LSTAT', 'CRIM', 'B', 'TAX')
# ('LSTAT', 'CRIM', 'B', 'AGE')
# ('LSTAT', 'CRIM', 'B', 'ZN')
# ('LSTAT', 'CRIM', 'CHAS', 'DIS')
# ('LSTAT', 'CRIM', 'CHAS', 'NOX')
# ('LSTAT', 'CRIM', 'CHAS', 'RAD')
# ('LSTAT', 'CRIM', 'CHAS', 'RM')
# ('LSTAT', 'CRIM', 'CHAS', 'TAX')
# ('LSTAT', 'CRIM', 'CHAS', 'AGE')
# ('LSTAT', 'CRIM', 'CHAS', 'ZN')
# ('LSTAT', 'CRIM', 'DIS', 'NOX')
# ('LSTAT', 'CRIM', 'DIS', 'RAD')
# ('LSTAT', 'CRIM', 'DIS', 'RM')
# ('LSTAT', 'CRIM', 'DIS', 'TAX')
# ('LSTAT', 'CRIM', 'DIS', 'AGE')
# ('LSTAT', 'CRIM', 'DIS', 'ZN')
# ('LSTAT', 'CRIM', 'NOX', 'RAD')
# ('LSTAT', 'CRIM', 'NOX', 'RM')
# ('LSTAT', 'CRIM', 'NOX', 'TAX')
# ('LSTAT', 'CRIM', 'NOX', 'AGE')
# ('LSTAT', 'CRIM', 'NOX', 'ZN')
# ('LSTAT', 'CRIM', 'RAD', 'RM')
# ('LSTAT', 'CRIM', 'RAD', 'TAX')
# ('LSTAT', 'CRIM', 'RAD', 'AGE')
# ('LSTAT', 'CRIM', 'RAD', 'ZN')
# ('LSTAT', 'CRIM', 'RM', 'TAX')
# ('LSTAT', 'CRIM', 'RM', 'AGE')
# ('LSTAT', 'CRIM', 'RM', 'ZN')
# ('LSTAT', 'CRIM', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS')
# ('LSTAT', 'PTRATIO', 'B', 'DIS')
# ('LSTAT', 'PTRATIO', 'B', 'NOX')
# ('LSTAT', 'PTRATIO', 'B', 'RAD')
# ('LSTAT', 'PTRATIO', 'B', 'RM')
# ('LSTAT', 'PTRATIO', 'B', 'TAX')
# ('LSTAT', 'PTRATIO', 'B', 'AGE')
# ('LSTAT', 'PTRATIO', 'B', 'ZN')
# ('LSTAT', 'PTRATIO', 'CHAS', 'DIS')
# ('LSTAT', 'PTRATIO', 'CHAS', 'NOX')
# ('LSTAT', 'PTRATIO', 'CHAS', 'RAD')
# ('LSTAT', 'PTRATIO', 'CHAS', 'RM')
# ('LSTAT', 'PTRATIO', 'CHAS', 'TAX')
# ('LSTAT', 'PTRATIO', 'CHAS', 'AGE')
# ('LSTAT', 'PTRATIO', 'CHAS', 'ZN')
# ('LSTAT', 'PTRATIO', 'DIS', 'NOX')
# ('LSTAT', 'PTRATIO', 'DIS', 'RAD')
# ('LSTAT', 'PTRATIO', 'DIS', 'RM')
# ('LSTAT', 'PTRATIO', 'DIS', 'TAX')
# ('LSTAT', 'PTRATIO', 'DIS', 'AGE')
# ('LSTAT', 'PTRATIO', 'DIS', 'ZN')
# ('LSTAT', 'PTRATIO', 'NOX', 'RAD')
# ('LSTAT', 'PTRATIO', 'NOX', 'RM')
# ('LSTAT', 'PTRATIO', 'NOX', 'TAX')
# ('LSTAT', 'PTRATIO', 'NOX', 'AGE')
# ('LSTAT', 'PTRATIO', 'NOX', 'ZN')
# ('LSTAT', 'PTRATIO', 'RAD', 'RM')
# ('LSTAT', 'PTRATIO', 'RAD', 'TAX')
# ('LSTAT', 'PTRATIO', 'RAD', 'AGE')
# ('LSTAT', 'PTRATIO', 'RAD', 'ZN')
# ('LSTAT', 'PTRATIO', 'RM', 'TAX')
# ('LSTAT', 'PTRATIO', 'RM', 'AGE')
# ('LSTAT', 'PTRATIO', 'RM', 'ZN')
# ('LSTAT', 'PTRATIO', 'TAX', 'AGE')
# ('LSTAT', 'PTRATIO', 'TAX', 'ZN')
# ('LSTAT', 'PTRATIO', 'AGE', 'ZN')
# ('LSTAT', 'B', 'CHAS', 'DIS')
# ('LSTAT', 'B', 'CHAS', 'NOX')
# ('LSTAT', 'B', 'CHAS', 'RAD')
# ('LSTAT', 'B', 'CHAS', 'RM')
# ('LSTAT', 'B', 'CHAS', 'TAX')
# ('LSTAT', 'B', 'CHAS', 'AGE')
# ('LSTAT', 'B', 'CHAS', 'ZN')
# ('LSTAT', 'B', 'DIS', 'NOX')
# ('LSTAT', 'B', 'DIS', 'RAD')
# ('LSTAT', 'B', 'DIS', 'RM')
# ('LSTAT', 'B', 'DIS', 'TAX')
# ('LSTAT', 'B', 'DIS', 'AGE')
# ('LSTAT', 'B', 'DIS', 'ZN')
# ('LSTAT', 'B', 'NOX', 'RAD')
# ('LSTAT', 'B', 'NOX', 'RM')
# ('LSTAT', 'B', 'NOX', 'TAX')
# ('LSTAT', 'B', 'NOX', 'AGE')
# ('LSTAT', 'B', 'NOX', 'ZN')
# ('LSTAT', 'B', 'RAD', 'RM')
# ('LSTAT', 'B', 'RAD', 'TAX')
# ('LSTAT', 'B', 'RAD', 'AGE')
# ('LSTAT', 'B', 'RAD', 'ZN')
# ('LSTAT', 'B', 'RM', 'TAX')
# ('LSTAT', 'B', 'RM', 'AGE')
# ('LSTAT', 'B', 'RM', 'ZN')
# ('LSTAT', 'B', 'TAX', 'AGE')
# ('LSTAT', 'B', 'TAX', 'ZN')
# ('LSTAT', 'B', 'AGE', 'ZN')
# ('LSTAT', 'CHAS', 'DIS', 'NOX')
# ('LSTAT', 'CHAS', 'DIS', 'RAD')
# ('LSTAT', 'CHAS', 'DIS', 'RM')
# ('LSTAT', 'CHAS', 'DIS', 'TAX')
# ('LSTAT', 'CHAS', 'DIS', 'AGE')
# ('LSTAT', 'CHAS', 'DIS', 'ZN')
# ('LSTAT', 'CHAS', 'NOX', 'RAD')
# ('LSTAT', 'CHAS', 'NOX', 'RM')
# ('LSTAT', 'CHAS', 'NOX', 'TAX')
# ('LSTAT', 'CHAS', 'NOX', 'AGE')
# ('LSTAT', 'CHAS', 'NOX', 'ZN')
# ('LSTAT', 'CHAS', 'RAD', 'RM')
# ('LSTAT', 'CHAS', 'RAD', 'TAX')
# ('LSTAT', 'CHAS', 'RAD', 'AGE')
# ('LSTAT', 'CHAS', 'RAD', 'ZN')
# ('LSTAT', 'CHAS', 'RM', 'TAX')
# ('LSTAT', 'CHAS', 'RM', 'AGE')
# ('LSTAT', 'CHAS', 'RM', 'ZN')
# ('LSTAT', 'CHAS', 'TAX', 'AGE')
# ('LSTAT', 'CHAS', 'TAX', 'ZN')
# ('LSTAT', 'CHAS', 'AGE', 'ZN')
# ('LSTAT', 'DIS', 'NOX', 'RAD')
# ('LSTAT', 'DIS', 'NOX', 'RM')
# ('LSTAT', 'DIS', 'NOX', 'TAX')
# ('LSTAT', 'DIS', 'NOX', 'AGE')
# ('LSTAT', 'DIS', 'NOX', 'ZN')
# ('LSTAT', 'DIS', 'RAD', 'RM')
# ('LSTAT', 'DIS', 'RAD', 'TAX')
# ('LSTAT', 'DIS', 'RAD', 'AGE')
# ('LSTAT', 'DIS', 'RAD', 'ZN')
# ('LSTAT', 'DIS', 'RM', 'TAX')
# ('LSTAT', 'DIS', 'RM', 'AGE')
# ('LSTAT', 'DIS', 'RM', 'ZN')
# ('LSTAT', 'DIS', 'TAX', 'AGE')
# ('LSTAT', 'DIS', 'TAX', 'ZN')
# ('LSTAT', 'DIS', 'AGE', 'ZN')
# ('LSTAT', 'NOX', 'RAD', 'RM')
# ('LSTAT', 'NOX', 'RAD', 'TAX')
# ('LSTAT', 'NOX', 'RAD', 'AGE')
# ('LSTAT', 'NOX', 'RAD', 'ZN')
# ('LSTAT', 'NOX', 'RM', 'TAX')
# ('LSTAT', 'NOX', 'RM', 'AGE')
# ('LSTAT', 'NOX', 'RM', 'ZN')
# ('LSTAT', 'NOX', 'TAX', 'AGE')
# ('LSTAT', 'NOX', 'TAX', 'ZN')
# ('LSTAT', 'NOX', 'AGE', 'ZN')
# ('LSTAT', 'RAD', 'RM', 'TAX')
# ('LSTAT', 'RAD', 'RM', 'AGE')
# ('LSTAT', 'RAD', 'RM', 'ZN')
# ('LSTAT', 'RAD', 'TAX', 'AGE')
# ('LSTAT', 'RAD', 'TAX', 'ZN')
# ('LSTAT', 'RAD', 'AGE', 'ZN')
# ('LSTAT', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B')
# ('INDUS', 'CRIM', 'PTRATIO', 'CHAS')
# ('INDUS', 'CRIM', 'PTRATIO', 'DIS')
# ('INDUS', 'CRIM', 'PTRATIO', 'NOX')
# ('INDUS', 'CRIM', 'PTRATIO', 'RAD')
# ('INDUS', 'CRIM', 'PTRATIO', 'RM')
# ('INDUS', 'CRIM', 'PTRATIO', 'TAX')
# ('INDUS', 'CRIM', 'PTRATIO', 'AGE')
# ('INDUS', 'CRIM', 'PTRATIO', 'ZN')
# ('INDUS', 'CRIM', 'B', 'CHAS')
# ('INDUS', 'CRIM', 'B', 'DIS')
# ('INDUS', 'CRIM', 'B', 'NOX')
# ('INDUS', 'CRIM', 'B', 'RAD')
# ('INDUS', 'CRIM', 'B', 'RM')
# ('INDUS', 'CRIM', 'B', 'TAX')
# ('INDUS', 'CRIM', 'B', 'AGE')
# ('INDUS', 'CRIM', 'B', 'ZN')
# ('INDUS', 'CRIM', 'CHAS', 'DIS')
# ('INDUS', 'CRIM', 'CHAS', 'NOX')
# ('INDUS', 'CRIM', 'CHAS', 'RAD')
# ('INDUS', 'CRIM', 'CHAS', 'RM')
# ('INDUS', 'CRIM', 'CHAS', 'TAX')
# ('INDUS', 'CRIM', 'CHAS', 'AGE')
# ('INDUS', 'CRIM', 'CHAS', 'ZN')
# ('INDUS', 'CRIM', 'DIS', 'NOX')
# ('INDUS', 'CRIM', 'DIS', 'RAD')
# ('INDUS', 'CRIM', 'DIS', 'RM')
# ('INDUS', 'CRIM', 'DIS', 'TAX')
# ('INDUS', 'CRIM', 'DIS', 'AGE')
# ('INDUS', 'CRIM', 'DIS', 'ZN')
# ('INDUS', 'CRIM', 'NOX', 'RAD')
# ('INDUS', 'CRIM', 'NOX', 'RM')
# ('INDUS', 'CRIM', 'NOX', 'TAX')
# ('INDUS', 'CRIM', 'NOX', 'AGE')
# ('INDUS', 'CRIM', 'NOX', 'ZN')
# ('INDUS', 'CRIM', 'RAD', 'RM')
# ('INDUS', 'CRIM', 'RAD', 'TAX')
# ('INDUS', 'CRIM', 'RAD', 'AGE')
# ('INDUS', 'CRIM', 'RAD', 'ZN')
# ('INDUS', 'CRIM', 'RM', 'TAX')
# ('INDUS', 'CRIM', 'RM', 'AGE')
# ('INDUS', 'CRIM', 'RM', 'ZN')
# ('INDUS', 'CRIM', 'TAX', 'AGE')
# ('INDUS', 'CRIM', 'TAX', 'ZN')
# ('INDUS', 'CRIM', 'AGE', 'ZN')
# ('INDUS', 'PTRATIO', 'B', 'CHAS')
# ('INDUS', 'PTRATIO', 'B', 'DIS')
# ('INDUS', 'PTRATIO', 'B', 'NOX')
# ('INDUS', 'PTRATIO', 'B', 'RAD')
# ('INDUS', 'PTRATIO', 'B', 'RM')
# ('INDUS', 'PTRATIO', 'B', 'TAX')
# ('INDUS', 'PTRATIO', 'B', 'AGE')
# ('INDUS', 'PTRATIO', 'B', 'ZN')
# ('INDUS', 'PTRATIO', 'CHAS', 'DIS')
# ('INDUS', 'PTRATIO', 'CHAS', 'NOX')
# ('INDUS', 'PTRATIO', 'CHAS', 'RAD')
# ('INDUS', 'PTRATIO', 'CHAS', 'RM')
# ('INDUS', 'PTRATIO', 'CHAS', 'TAX')
# ('INDUS', 'PTRATIO', 'CHAS', 'AGE')
# ('INDUS', 'PTRATIO', 'CHAS', 'ZN')
# ('INDUS', 'PTRATIO', 'DIS', 'NOX')
# ('INDUS', 'PTRATIO', 'DIS', 'RAD')
# ('INDUS', 'PTRATIO', 'DIS', 'RM')
# ('INDUS', 'PTRATIO', 'DIS', 'TAX')
# ('INDUS', 'PTRATIO', 'DIS', 'AGE')
# ('INDUS', 'PTRATIO', 'DIS', 'ZN')
# ('INDUS', 'PTRATIO', 'NOX', 'RAD')
# ('INDUS', 'PTRATIO', 'NOX', 'RM')
# ('INDUS', 'PTRATIO', 'NOX', 'TAX')
# ('INDUS', 'PTRATIO', 'NOX', 'AGE')
# ('INDUS', 'PTRATIO', 'NOX', 'ZN')
# ('INDUS', 'PTRATIO', 'RAD', 'RM')
# ('INDUS', 'PTRATIO', 'RAD', 'TAX')
# ('INDUS', 'PTRATIO', 'RAD', 'AGE')
# ('INDUS', 'PTRATIO', 'RAD', 'ZN')
# ('INDUS', 'PTRATIO', 'RM', 'TAX')
# ('INDUS', 'PTRATIO', 'RM', 'AGE')
# ('INDUS', 'PTRATIO', 'RM', 'ZN')
# ('INDUS', 'PTRATIO', 'TAX', 'AGE')
# ('INDUS', 'PTRATIO', 'TAX', 'ZN')
# ('INDUS', 'PTRATIO', 'AGE', 'ZN')
# ('INDUS', 'B', 'CHAS', 'DIS')
# ('INDUS', 'B', 'CHAS', 'NOX')
# ('INDUS', 'B', 'CHAS', 'RAD')
# ('INDUS', 'B', 'CHAS', 'RM')
# ('INDUS', 'B', 'CHAS', 'TAX')
# ('INDUS', 'B', 'CHAS', 'AGE')
# ('INDUS', 'B', 'CHAS', 'ZN')
# ('INDUS', 'B', 'DIS', 'NOX')
# ('INDUS', 'B', 'DIS', 'RAD')
# ('INDUS', 'B', 'DIS', 'RM')
# ('INDUS', 'B', 'DIS', 'TAX')
# ('INDUS', 'B', 'DIS', 'AGE')
# ('INDUS', 'B', 'DIS', 'ZN')
# ('INDUS', 'B', 'NOX', 'RAD')
# ('INDUS', 'B', 'NOX', 'RM')
# ('INDUS', 'B', 'NOX', 'TAX')
# ('INDUS', 'B', 'NOX', 'AGE')
# ('INDUS', 'B', 'NOX', 'ZN')
# ('INDUS', 'B', 'RAD', 'RM')
# ('INDUS', 'B', 'RAD', 'TAX')
# ('INDUS', 'B', 'RAD', 'AGE')
# ('INDUS', 'B', 'RAD', 'ZN')
# ('INDUS', 'B', 'RM', 'TAX')
# ('INDUS', 'B', 'RM', 'AGE')
# ('INDUS', 'B', 'RM', 'ZN')
# ('INDUS', 'B', 'TAX', 'AGE')
# ('INDUS', 'B', 'TAX', 'ZN')
# ('INDUS', 'B', 'AGE', 'ZN')
# ('INDUS', 'CHAS', 'DIS', 'NOX')
# ('INDUS', 'CHAS', 'DIS', 'RAD')
# ('INDUS', 'CHAS', 'DIS', 'RM')
# ('INDUS', 'CHAS', 'DIS', 'TAX')
# ('INDUS', 'CHAS', 'DIS', 'AGE')
# ('INDUS', 'CHAS', 'DIS', 'ZN')
# ('INDUS', 'CHAS', 'NOX', 'RAD')
# ('INDUS', 'CHAS', 'NOX', 'RM')
# ('INDUS', 'CHAS', 'NOX', 'TAX')
# ('INDUS', 'CHAS', 'NOX', 'AGE')
# ('INDUS', 'CHAS', 'NOX', 'ZN')
# ('INDUS', 'CHAS', 'RAD', 'RM')
# ('INDUS', 'CHAS', 'RAD', 'TAX')
# ('INDUS', 'CHAS', 'RAD', 'AGE')
# ('INDUS', 'CHAS', 'RAD', 'ZN')
# ('INDUS', 'CHAS', 'RM', 'TAX')
# ('INDUS', 'CHAS', 'RM', 'AGE')
# ('INDUS', 'CHAS', 'RM', 'ZN')
# ('INDUS', 'CHAS', 'TAX', 'AGE')
# ('INDUS', 'CHAS', 'TAX', 'ZN')
# ('INDUS', 'CHAS', 'AGE', 'ZN')
# ('INDUS', 'DIS', 'NOX', 'RAD')
# ('INDUS', 'DIS', 'NOX', 'RM')
# ('INDUS', 'DIS', 'NOX', 'TAX')
# ('INDUS', 'DIS', 'NOX', 'AGE')
# ('INDUS', 'DIS', 'NOX', 'ZN')
# ('INDUS', 'DIS', 'RAD', 'RM')
# ('INDUS', 'DIS', 'RAD', 'TAX')
# ('INDUS', 'DIS', 'RAD', 'AGE')
# ('INDUS', 'DIS', 'RAD', 'ZN')
# ('INDUS', 'DIS', 'RM', 'TAX')
# ('INDUS', 'DIS', 'RM', 'AGE')
# ('INDUS', 'DIS', 'RM', 'ZN')
# ('INDUS', 'DIS', 'TAX', 'AGE')
# ('INDUS', 'DIS', 'TAX', 'ZN')
# ('INDUS', 'DIS', 'AGE', 'ZN')
# ('INDUS', 'NOX', 'RAD', 'RM')
# ('INDUS', 'NOX', 'RAD', 'TAX')
# ('INDUS', 'NOX', 'RAD', 'AGE')
# ('INDUS', 'NOX', 'RAD', 'ZN')
# ('INDUS', 'NOX', 'RM', 'TAX')
# ('INDUS', 'NOX', 'RM', 'AGE')
# ('INDUS', 'NOX', 'RM', 'ZN')
# ('INDUS', 'NOX', 'TAX', 'AGE')
# ('INDUS', 'NOX', 'TAX', 'ZN')
# ('INDUS', 'NOX', 'AGE', 'ZN')
# ('INDUS', 'RAD', 'RM', 'TAX')
# ('INDUS', 'RAD', 'RM', 'AGE')
# ('INDUS', 'RAD', 'RM', 'ZN')
# ('INDUS', 'RAD', 'TAX', 'AGE')
# ('INDUS', 'RAD', 'TAX', 'ZN')
# ('INDUS', 'RAD', 'AGE', 'ZN')
# ('INDUS', 'RM', 'TAX', 'AGE')
# ('INDUS', 'RM', 'TAX', 'ZN')
# ('INDUS', 'RM', 'AGE', 'ZN')
# ('INDUS', 'TAX', 'AGE', 'ZN')
# ('CRIM', 'PTRATIO', 'B', 'CHAS')
# ('CRIM', 'PTRATIO', 'B', 'DIS')
# ('CRIM', 'PTRATIO', 'B', 'NOX')
# ('CRIM', 'PTRATIO', 'B', 'RAD')
# ('CRIM', 'PTRATIO', 'B', 'RM')
# ('CRIM', 'PTRATIO', 'B', 'TAX')
# ('CRIM', 'PTRATIO', 'B', 'AGE')
# ('CRIM', 'PTRATIO', 'B', 'ZN')
# ('CRIM', 'PTRATIO', 'CHAS', 'DIS')
# ('CRIM', 'PTRATIO', 'CHAS', 'NOX')
# ('CRIM', 'PTRATIO', 'CHAS', 'RAD')
# ('CRIM', 'PTRATIO', 'CHAS', 'RM')
# ('CRIM', 'PTRATIO', 'CHAS', 'TAX')
# ('CRIM', 'PTRATIO', 'CHAS', 'AGE')
# ('CRIM', 'PTRATIO', 'CHAS', 'ZN')
# ('CRIM', 'PTRATIO', 'DIS', 'NOX')
# ('CRIM', 'PTRATIO', 'DIS', 'RAD')
# ('CRIM', 'PTRATIO', 'DIS', 'RM')
# ('CRIM', 'PTRATIO', 'DIS', 'TAX')
# ('CRIM', 'PTRATIO', 'DIS', 'AGE')
# ('CRIM', 'PTRATIO', 'DIS', 'ZN')
# ('CRIM', 'PTRATIO', 'NOX', 'RAD')
# ('CRIM', 'PTRATIO', 'NOX', 'RM')
# ('CRIM', 'PTRATIO', 'NOX', 'TAX')
# ('CRIM', 'PTRATIO', 'NOX', 'AGE')
# ('CRIM', 'PTRATIO', 'NOX', 'ZN')
# ('CRIM', 'PTRATIO', 'RAD', 'RM')
# ('CRIM', 'PTRATIO', 'RAD', 'TAX')
# ('CRIM', 'PTRATIO', 'RAD', 'AGE')
# ('CRIM', 'PTRATIO', 'RAD', 'ZN')
# ('CRIM', 'PTRATIO', 'RM', 'TAX')
# ('CRIM', 'PTRATIO', 'RM', 'AGE')
# ('CRIM', 'PTRATIO', 'RM', 'ZN')
# ('CRIM', 'PTRATIO', 'TAX', 'AGE')
# ('CRIM', 'PTRATIO', 'TAX', 'ZN')
# ('CRIM', 'PTRATIO', 'AGE', 'ZN')
# ('CRIM', 'B', 'CHAS', 'DIS')
# ('CRIM', 'B', 'CHAS', 'NOX')
# ('CRIM', 'B', 'CHAS', 'RAD')
# ('CRIM', 'B', 'CHAS', 'RM')
# ('CRIM', 'B', 'CHAS', 'TAX')
# ('CRIM', 'B', 'CHAS', 'AGE')
# ('CRIM', 'B', 'CHAS', 'ZN')
# ('CRIM', 'B', 'DIS', 'NOX')
# ('CRIM', 'B', 'DIS', 'RAD')
# ('CRIM', 'B', 'DIS', 'RM')
# ('CRIM', 'B', 'DIS', 'TAX')
# ('CRIM', 'B', 'DIS', 'AGE')
# ('CRIM', 'B', 'DIS', 'ZN')
# ('CRIM', 'B', 'NOX', 'RAD')
# ('CRIM', 'B', 'NOX', 'RM')
# ('CRIM', 'B', 'NOX', 'TAX')
# ('CRIM', 'B', 'NOX', 'AGE')
# ('CRIM', 'B', 'NOX', 'ZN')
# ('CRIM', 'B', 'RAD', 'RM')
# ('CRIM', 'B', 'RAD', 'TAX')
# ('CRIM', 'B', 'RAD', 'AGE')
# ('CRIM', 'B', 'RAD', 'ZN')
# ('CRIM', 'B', 'RM', 'TAX')
# ('CRIM', 'B', 'RM', 'AGE')
# ('CRIM', 'B', 'RM', 'ZN')
# ('CRIM', 'B', 'TAX', 'AGE')
# ('CRIM', 'B', 'TAX', 'ZN')
# ('CRIM', 'B', 'AGE', 'ZN')
# ('CRIM', 'CHAS', 'DIS', 'NOX')
# ('CRIM', 'CHAS', 'DIS', 'RAD')
# ('CRIM', 'CHAS', 'DIS', 'RM')
# ('CRIM', 'CHAS', 'DIS', 'TAX')
# ('CRIM', 'CHAS', 'DIS', 'AGE')
# ('CRIM', 'CHAS', 'DIS', 'ZN')
# ('CRIM', 'CHAS', 'NOX', 'RAD')
# ('CRIM', 'CHAS', 'NOX', 'RM')
# ('CRIM', 'CHAS', 'NOX', 'TAX')
# ('CRIM', 'CHAS', 'NOX', 'AGE')
# ('CRIM', 'CHAS', 'NOX', 'ZN')
# ('CRIM', 'CHAS', 'RAD', 'RM')
# ('CRIM', 'CHAS', 'RAD', 'TAX')
# ('CRIM', 'CHAS', 'RAD', 'AGE')
# ('CRIM', 'CHAS', 'RAD', 'ZN')
# ('CRIM', 'CHAS', 'RM', 'TAX')
# ('CRIM', 'CHAS', 'RM', 'AGE')
# ('CRIM', 'CHAS', 'RM', 'ZN')
# ('CRIM', 'CHAS', 'TAX', 'AGE')
# ('CRIM', 'CHAS', 'TAX', 'ZN')
# ('CRIM', 'CHAS', 'AGE', 'ZN')
# ('CRIM', 'DIS', 'NOX', 'RAD')
# ('CRIM', 'DIS', 'NOX', 'RM')
# ('CRIM', 'DIS', 'NOX', 'TAX')
# ('CRIM', 'DIS', 'NOX', 'AGE')
# ('CRIM', 'DIS', 'NOX', 'ZN')
# ('CRIM', 'DIS', 'RAD', 'RM')
# ('CRIM', 'DIS', 'RAD', 'TAX')
# ('CRIM', 'DIS', 'RAD', 'AGE')
# ('CRIM', 'DIS', 'RAD', 'ZN')
# ('CRIM', 'DIS', 'RM', 'TAX')
# ('CRIM', 'DIS', 'RM', 'AGE')
# ('CRIM', 'DIS', 'RM', 'ZN')
# ('CRIM', 'DIS', 'TAX', 'AGE')
# ('CRIM', 'DIS', 'TAX', 'ZN')
# ('CRIM', 'DIS', 'AGE', 'ZN')
# ('CRIM', 'NOX', 'RAD', 'RM')
# ('CRIM', 'NOX', 'RAD', 'TAX')
# ('CRIM', 'NOX', 'RAD', 'AGE')
# ('CRIM', 'NOX', 'RAD', 'ZN')
# ('CRIM', 'NOX', 'RM', 'TAX')
# ('CRIM', 'NOX', 'RM', 'AGE')
# ('CRIM', 'NOX', 'RM', 'ZN')
# ('CRIM', 'NOX', 'TAX', 'AGE')
# ('CRIM', 'NOX', 'TAX', 'ZN')
# ('CRIM', 'NOX', 'AGE', 'ZN')
# ('CRIM', 'RAD', 'RM', 'TAX')
# ('CRIM', 'RAD', 'RM', 'AGE')
# ('CRIM', 'RAD', 'RM', 'ZN')
# ('CRIM', 'RAD', 'TAX', 'AGE')
# ('CRIM', 'RAD', 'TAX', 'ZN')
# ('CRIM', 'RAD', 'AGE', 'ZN')
# ('CRIM', 'RM', 'TAX', 'AGE')
# ('CRIM', 'RM', 'TAX', 'ZN')
# ('CRIM', 'RM', 'AGE', 'ZN')
# ('CRIM', 'TAX', 'AGE', 'ZN')
# ('PTRATIO', 'B', 'CHAS', 'DIS')
# ('PTRATIO', 'B', 'CHAS', 'NOX')
# ('PTRATIO', 'B', 'CHAS', 'RAD')
# ('PTRATIO', 'B', 'CHAS', 'RM')
# ('PTRATIO', 'B', 'CHAS', 'TAX')
# ('PTRATIO', 'B', 'CHAS', 'AGE')
# ('PTRATIO', 'B', 'CHAS', 'ZN')
# ('PTRATIO', 'B', 'DIS', 'NOX')
# ('PTRATIO', 'B', 'DIS', 'RAD')
# ('PTRATIO', 'B', 'DIS', 'RM')
# ('PTRATIO', 'B', 'DIS', 'TAX')
# ('PTRATIO', 'B', 'DIS', 'AGE')
# ('PTRATIO', 'B', 'DIS', 'ZN')
# ('PTRATIO', 'B', 'NOX', 'RAD')
# ('PTRATIO', 'B', 'NOX', 'RM')
# ('PTRATIO', 'B', 'NOX', 'TAX')
# ('PTRATIO', 'B', 'NOX', 'AGE')
# ('PTRATIO', 'B', 'NOX', 'ZN')
# ('PTRATIO', 'B', 'RAD', 'RM')
# ('PTRATIO', 'B', 'RAD', 'TAX')
# ('PTRATIO', 'B', 'RAD', 'AGE')
# ('PTRATIO', 'B', 'RAD', 'ZN')
# ('PTRATIO', 'B', 'RM', 'TAX')
# ('PTRATIO', 'B', 'RM', 'AGE')
# ('PTRATIO', 'B', 'RM', 'ZN')
# ('PTRATIO', 'B', 'TAX', 'AGE')
# ('PTRATIO', 'B', 'TAX', 'ZN')
# ('PTRATIO', 'B', 'AGE', 'ZN')
# ('PTRATIO', 'CHAS', 'DIS', 'NOX')
# ('PTRATIO', 'CHAS', 'DIS', 'RAD')
# ('PTRATIO', 'CHAS', 'DIS', 'RM')
# ('PTRATIO', 'CHAS', 'DIS', 'TAX')
# ('PTRATIO', 'CHAS', 'DIS', 'AGE')
# ('PTRATIO', 'CHAS', 'DIS', 'ZN')
# ('PTRATIO', 'CHAS', 'NOX', 'RAD')
# ('PTRATIO', 'CHAS', 'NOX', 'RM')
# ('PTRATIO', 'CHAS', 'NOX', 'TAX')
# ('PTRATIO', 'CHAS', 'NOX', 'AGE')
# ('PTRATIO', 'CHAS', 'NOX', 'ZN')
# ('PTRATIO', 'CHAS', 'RAD', 'RM')
# ('PTRATIO', 'CHAS', 'RAD', 'TAX')
# ('PTRATIO', 'CHAS', 'RAD', 'AGE')
# ('PTRATIO', 'CHAS', 'RAD', 'ZN')
# ('PTRATIO', 'CHAS', 'RM', 'TAX')
# ('PTRATIO', 'CHAS', 'RM', 'AGE')
# ('PTRATIO', 'CHAS', 'RM', 'ZN')
# ('PTRATIO', 'CHAS', 'TAX', 'AGE')
# ('PTRATIO', 'CHAS', 'TAX', 'ZN')
# ('PTRATIO', 'CHAS', 'AGE', 'ZN')
# ('PTRATIO', 'DIS', 'NOX', 'RAD')
# ('PTRATIO', 'DIS', 'NOX', 'RM')
# ('PTRATIO', 'DIS', 'NOX', 'TAX')
# ('PTRATIO', 'DIS', 'NOX', 'AGE')
# ('PTRATIO', 'DIS', 'NOX', 'ZN')
# ('PTRATIO', 'DIS', 'RAD', 'RM')
# ('PTRATIO', 'DIS', 'RAD', 'TAX')
# ('PTRATIO', 'DIS', 'RAD', 'AGE')
# ('PTRATIO', 'DIS', 'RAD', 'ZN')
# ('PTRATIO', 'DIS', 'RM', 'TAX')
# ('PTRATIO', 'DIS', 'RM', 'AGE')
# ('PTRATIO', 'DIS', 'RM', 'ZN')
# ('PTRATIO', 'DIS', 'TAX', 'AGE')
# ('PTRATIO', 'DIS', 'TAX', 'ZN')
# ('PTRATIO', 'DIS', 'AGE', 'ZN')
# ('PTRATIO', 'NOX', 'RAD', 'RM')
# ('PTRATIO', 'NOX', 'RAD', 'TAX')
# ('PTRATIO', 'NOX', 'RAD', 'AGE')
# ('PTRATIO', 'NOX', 'RAD', 'ZN')
# ('PTRATIO', 'NOX', 'RM', 'TAX')
# ('PTRATIO', 'NOX', 'RM', 'AGE')
# ('PTRATIO', 'NOX', 'RM', 'ZN')
# ('PTRATIO', 'NOX', 'TAX', 'AGE')
# ('PTRATIO', 'NOX', 'TAX', 'ZN')
# ('PTRATIO', 'NOX', 'AGE', 'ZN')
# ('PTRATIO', 'RAD', 'RM', 'TAX')
# ('PTRATIO', 'RAD', 'RM', 'AGE')
# ('PTRATIO', 'RAD', 'RM', 'ZN')
# ('PTRATIO', 'RAD', 'TAX', 'AGE')
# ('PTRATIO', 'RAD', 'TAX', 'ZN')
# ('PTRATIO', 'RAD', 'AGE', 'ZN')
# ('PTRATIO', 'RM', 'TAX', 'AGE')
# ('PTRATIO', 'RM', 'TAX', 'ZN')
# ('PTRATIO', 'RM', 'AGE', 'ZN')
# ('PTRATIO', 'TAX', 'AGE', 'ZN')
# ('B', 'CHAS', 'DIS', 'NOX')
# ('B', 'CHAS', 'DIS', 'RAD')
# ('B', 'CHAS', 'DIS', 'RM')
# ('B', 'CHAS', 'DIS', 'TAX')
# ('B', 'CHAS', 'DIS', 'AGE')
# ('B', 'CHAS', 'DIS', 'ZN')
# ('B', 'CHAS', 'NOX', 'RAD')
# ('B', 'CHAS', 'NOX', 'RM')
# ('B', 'CHAS', 'NOX', 'TAX')
# ('B', 'CHAS', 'NOX', 'AGE')
# ('B', 'CHAS', 'NOX', 'ZN')
# ('B', 'CHAS', 'RAD', 'RM')
# ('B', 'CHAS', 'RAD', 'TAX')
# ('B', 'CHAS', 'RAD', 'AGE')
# ('B', 'CHAS', 'RAD', 'ZN')
# ('B', 'CHAS', 'RM', 'TAX')
# ('B', 'CHAS', 'RM', 'AGE')
# ('B', 'CHAS', 'RM', 'ZN')
# ('B', 'CHAS', 'TAX', 'AGE')
# ('B', 'CHAS', 'TAX', 'ZN')
# ('B', 'CHAS', 'AGE', 'ZN')
# ('B', 'DIS', 'NOX', 'RAD')
# ('B', 'DIS', 'NOX', 'RM')
# ('B', 'DIS', 'NOX', 'TAX')
# ('B', 'DIS', 'NOX', 'AGE')
# ('B', 'DIS', 'NOX', 'ZN')
# ('B', 'DIS', 'RAD', 'RM')
# ('B', 'DIS', 'RAD', 'TAX')
# ('B', 'DIS', 'RAD', 'AGE')
# ('B', 'DIS', 'RAD', 'ZN')
# ('B', 'DIS', 'RM', 'TAX')
# ('B', 'DIS', 'RM', 'AGE')
# ('B', 'DIS', 'RM', 'ZN')
# ('B', 'DIS', 'TAX', 'AGE')
# ('B', 'DIS', 'TAX', 'ZN')
# ('B', 'DIS', 'AGE', 'ZN')
# ('B', 'NOX', 'RAD', 'RM')
# ('B', 'NOX', 'RAD', 'TAX')
# ('B', 'NOX', 'RAD', 'AGE')
# ('B', 'NOX', 'RAD', 'ZN')
# ('B', 'NOX', 'RM', 'TAX')
# ('B', 'NOX', 'RM', 'AGE')
# ('B', 'NOX', 'RM', 'ZN')
# ('B', 'NOX', 'TAX', 'AGE')
# ('B', 'NOX', 'TAX', 'ZN')
# ('B', 'NOX', 'AGE', 'ZN')
# ('B', 'RAD', 'RM', 'TAX')
# ('B', 'RAD', 'RM', 'AGE')
# ('B', 'RAD', 'RM', 'ZN')
# ('B', 'RAD', 'TAX', 'AGE')
# ('B', 'RAD', 'TAX', 'ZN')
# ('B', 'RAD', 'AGE', 'ZN')
# ('B', 'RM', 'TAX', 'AGE')
# ('B', 'RM', 'TAX', 'ZN')
# ('B', 'RM', 'AGE', 'ZN')
# ('B', 'TAX', 'AGE', 'ZN')
# ('CHAS', 'DIS', 'NOX', 'RAD')
# ('CHAS', 'DIS', 'NOX', 'RM')
# ('CHAS', 'DIS', 'NOX', 'TAX')
# ('CHAS', 'DIS', 'NOX', 'AGE')
# ('CHAS', 'DIS', 'NOX', 'ZN')
# ('CHAS', 'DIS', 'RAD', 'RM')
# ('CHAS', 'DIS', 'RAD', 'TAX')
# ('CHAS', 'DIS', 'RAD', 'AGE')
# ('CHAS', 'DIS', 'RAD', 'ZN')
# ('CHAS', 'DIS', 'RM', 'TAX')
# ('CHAS', 'DIS', 'RM', 'AGE')
# ('CHAS', 'DIS', 'RM', 'ZN')
# ('CHAS', 'DIS', 'TAX', 'AGE')
# ('CHAS', 'DIS', 'TAX', 'ZN')
# ('CHAS', 'DIS', 'AGE', 'ZN')
# ('CHAS', 'NOX', 'RAD', 'RM')
# ('CHAS', 'NOX', 'RAD', 'TAX')
# ('CHAS', 'NOX', 'RAD', 'AGE')
# ('CHAS', 'NOX', 'RAD', 'ZN')
# ('CHAS', 'NOX', 'RM', 'TAX')
# ('CHAS', 'NOX', 'RM', 'AGE')
# ('CHAS', 'NOX', 'RM', 'ZN')
# ('CHAS', 'NOX', 'TAX', 'AGE')
# ('CHAS', 'NOX', 'TAX', 'ZN')
# ('CHAS', 'NOX', 'AGE', 'ZN')
# ('CHAS', 'RAD', 'RM', 'TAX')
# ('CHAS', 'RAD', 'RM', 'AGE')
# ('CHAS', 'RAD', 'RM', 'ZN')
# ('CHAS', 'RAD', 'TAX', 'AGE')
# ('CHAS', 'RAD', 'TAX', 'ZN')
# ('CHAS', 'RAD', 'AGE', 'ZN')
# ('CHAS', 'RM', 'TAX', 'AGE')
# ('CHAS', 'RM', 'TAX', 'ZN')
# ('CHAS', 'RM', 'AGE', 'ZN')
# ('CHAS', 'TAX', 'AGE', 'ZN')
# ('DIS', 'NOX', 'RAD', 'RM')
# ('DIS', 'NOX', 'RAD', 'TAX')
# ('DIS', 'NOX', 'RAD', 'AGE')
# ('DIS', 'NOX', 'RAD', 'ZN')
# ('DIS', 'NOX', 'RM', 'TAX')
# ('DIS', 'NOX', 'RM', 'AGE')
# ('DIS', 'NOX', 'RM', 'ZN')
# ('DIS', 'NOX', 'TAX', 'AGE')
# ('DIS', 'NOX', 'TAX', 'ZN')
# ('DIS', 'NOX', 'AGE', 'ZN')
# ('DIS', 'RAD', 'RM', 'TAX')
# ('DIS', 'RAD', 'RM', 'AGE')
# ('DIS', 'RAD', 'RM', 'ZN')
# ('DIS', 'RAD', 'TAX', 'AGE')
# ('DIS', 'RAD', 'TAX', 'ZN')
# ('DIS', 'RAD', 'AGE', 'ZN')
# ('DIS', 'RM', 'TAX', 'AGE')
# ('DIS', 'RM', 'TAX', 'ZN')
# ('DIS', 'RM', 'AGE', 'ZN')
# ('DIS', 'TAX', 'AGE', 'ZN')
# ('NOX', 'RAD', 'RM', 'TAX')
# ('NOX', 'RAD', 'RM', 'AGE')
# ('NOX', 'RAD', 'RM', 'ZN')
# ('NOX', 'RAD', 'TAX', 'AGE')
# ('NOX', 'RAD', 'TAX', 'ZN')
# ('NOX', 'RAD', 'AGE', 'ZN')
# ('NOX', 'RM', 'TAX', 'AGE')
# ('NOX', 'RM', 'TAX', 'ZN')
# ('NOX', 'RM', 'AGE', 'ZN')
# ('NOX', 'TAX', 'AGE', 'ZN')
# ('RAD', 'RM', 'TAX', 'AGE')
# ('RAD', 'RM', 'TAX', 'ZN')
# ('RAD', 'RM', 'AGE', 'ZN')
# ('RAD', 'TAX', 'AGE', 'ZN')
# ('RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'CHAS')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'DIS')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'NOX')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'RAD')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'RM')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'TAX')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'CHAS')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'DIS')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'NOX')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'RAD')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'RM')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'TAX')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'CHAS', 'DIS')
# ('LSTAT', 'INDUS', 'CRIM', 'CHAS', 'NOX')
# ('LSTAT', 'INDUS', 'CRIM', 'CHAS', 'RAD')
# ('LSTAT', 'INDUS', 'CRIM', 'CHAS', 'RM')
# ('LSTAT', 'INDUS', 'CRIM', 'CHAS', 'TAX')
# ('LSTAT', 'INDUS', 'CRIM', 'CHAS', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'CHAS', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'DIS', 'NOX')
# ('LSTAT', 'INDUS', 'CRIM', 'DIS', 'RAD')
# ('LSTAT', 'INDUS', 'CRIM', 'DIS', 'RM')
# ('LSTAT', 'INDUS', 'CRIM', 'DIS', 'TAX')
# ('LSTAT', 'INDUS', 'CRIM', 'DIS', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'DIS', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'NOX', 'RAD')
# ('LSTAT', 'INDUS', 'CRIM', 'NOX', 'RM')
# ('LSTAT', 'INDUS', 'CRIM', 'NOX', 'TAX')
# ('LSTAT', 'INDUS', 'CRIM', 'NOX', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'NOX', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'RAD', 'RM')
# ('LSTAT', 'INDUS', 'CRIM', 'RAD', 'TAX')
# ('LSTAT', 'INDUS', 'CRIM', 'RAD', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'RAD', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'RM', 'TAX')
# ('LSTAT', 'INDUS', 'CRIM', 'RM', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'RM', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'CHAS')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'DIS')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'NOX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'RAD')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'RM')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'TAX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'AGE')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'CHAS', 'DIS')
# ('LSTAT', 'INDUS', 'PTRATIO', 'CHAS', 'NOX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'CHAS', 'RAD')
# ('LSTAT', 'INDUS', 'PTRATIO', 'CHAS', 'RM')
# ('LSTAT', 'INDUS', 'PTRATIO', 'CHAS', 'TAX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'CHAS', 'AGE')
# ('LSTAT', 'INDUS', 'PTRATIO', 'CHAS', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'DIS', 'NOX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'DIS', 'RAD')
# ('LSTAT', 'INDUS', 'PTRATIO', 'DIS', 'RM')
# ('LSTAT', 'INDUS', 'PTRATIO', 'DIS', 'TAX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'DIS', 'AGE')
# ('LSTAT', 'INDUS', 'PTRATIO', 'DIS', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'NOX', 'RAD')
# ('LSTAT', 'INDUS', 'PTRATIO', 'NOX', 'RM')
# ('LSTAT', 'INDUS', 'PTRATIO', 'NOX', 'TAX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'NOX', 'AGE')
# ('LSTAT', 'INDUS', 'PTRATIO', 'NOX', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'RAD', 'RM')
# ('LSTAT', 'INDUS', 'PTRATIO', 'RAD', 'TAX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'RAD', 'AGE')
# ('LSTAT', 'INDUS', 'PTRATIO', 'RAD', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'RM', 'TAX')
# ('LSTAT', 'INDUS', 'PTRATIO', 'RM', 'AGE')
# ('LSTAT', 'INDUS', 'PTRATIO', 'RM', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'PTRATIO', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'B', 'CHAS', 'DIS')
# ('LSTAT', 'INDUS', 'B', 'CHAS', 'NOX')
# ('LSTAT', 'INDUS', 'B', 'CHAS', 'RAD')
# ('LSTAT', 'INDUS', 'B', 'CHAS', 'RM')
# ('LSTAT', 'INDUS', 'B', 'CHAS', 'TAX')
# ('LSTAT', 'INDUS', 'B', 'CHAS', 'AGE')
# ('LSTAT', 'INDUS', 'B', 'CHAS', 'ZN')
# ('LSTAT', 'INDUS', 'B', 'DIS', 'NOX')
# ('LSTAT', 'INDUS', 'B', 'DIS', 'RAD')
# ('LSTAT', 'INDUS', 'B', 'DIS', 'RM')
# ('LSTAT', 'INDUS', 'B', 'DIS', 'TAX')
# ('LSTAT', 'INDUS', 'B', 'DIS', 'AGE')
# ('LSTAT', 'INDUS', 'B', 'DIS', 'ZN')
# ('LSTAT', 'INDUS', 'B', 'NOX', 'RAD')
# ('LSTAT', 'INDUS', 'B', 'NOX', 'RM')
# ('LSTAT', 'INDUS', 'B', 'NOX', 'TAX')
# ('LSTAT', 'INDUS', 'B', 'NOX', 'AGE')
# ('LSTAT', 'INDUS', 'B', 'NOX', 'ZN')
# ('LSTAT', 'INDUS', 'B', 'RAD', 'RM')
# ('LSTAT', 'INDUS', 'B', 'RAD', 'TAX')
# ('LSTAT', 'INDUS', 'B', 'RAD', 'AGE')
# ('LSTAT', 'INDUS', 'B', 'RAD', 'ZN')
# ('LSTAT', 'INDUS', 'B', 'RM', 'TAX')
# ('LSTAT', 'INDUS', 'B', 'RM', 'AGE')
# ('LSTAT', 'INDUS', 'B', 'RM', 'ZN')
# ('LSTAT', 'INDUS', 'B', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'B', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'B', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CHAS', 'DIS', 'NOX')
# ('LSTAT', 'INDUS', 'CHAS', 'DIS', 'RAD')
# ('LSTAT', 'INDUS', 'CHAS', 'DIS', 'RM')
# ('LSTAT', 'INDUS', 'CHAS', 'DIS', 'TAX')
# ('LSTAT', 'INDUS', 'CHAS', 'DIS', 'AGE')
# ('LSTAT', 'INDUS', 'CHAS', 'DIS', 'ZN')
# ('LSTAT', 'INDUS', 'CHAS', 'NOX', 'RAD')
# ('LSTAT', 'INDUS', 'CHAS', 'NOX', 'RM')
# ('LSTAT', 'INDUS', 'CHAS', 'NOX', 'TAX')
# ('LSTAT', 'INDUS', 'CHAS', 'NOX', 'AGE')
# ('LSTAT', 'INDUS', 'CHAS', 'NOX', 'ZN')
# ('LSTAT', 'INDUS', 'CHAS', 'RAD', 'RM')
# ('LSTAT', 'INDUS', 'CHAS', 'RAD', 'TAX')
# ('LSTAT', 'INDUS', 'CHAS', 'RAD', 'AGE')
# ('LSTAT', 'INDUS', 'CHAS', 'RAD', 'ZN')
# ('LSTAT', 'INDUS', 'CHAS', 'RM', 'TAX')
# ('LSTAT', 'INDUS', 'CHAS', 'RM', 'AGE')
# ('LSTAT', 'INDUS', 'CHAS', 'RM', 'ZN')
# ('LSTAT', 'INDUS', 'CHAS', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'CHAS', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'CHAS', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'DIS', 'NOX', 'RAD')
# ('LSTAT', 'INDUS', 'DIS', 'NOX', 'RM')
# ('LSTAT', 'INDUS', 'DIS', 'NOX', 'TAX')
# ('LSTAT', 'INDUS', 'DIS', 'NOX', 'AGE')
# ('LSTAT', 'INDUS', 'DIS', 'NOX', 'ZN')
# ('LSTAT', 'INDUS', 'DIS', 'RAD', 'RM')
# ('LSTAT', 'INDUS', 'DIS', 'RAD', 'TAX')
# ('LSTAT', 'INDUS', 'DIS', 'RAD', 'AGE')
# ('LSTAT', 'INDUS', 'DIS', 'RAD', 'ZN')
# ('LSTAT', 'INDUS', 'DIS', 'RM', 'TAX')
# ('LSTAT', 'INDUS', 'DIS', 'RM', 'AGE')
# ('LSTAT', 'INDUS', 'DIS', 'RM', 'ZN')
# ('LSTAT', 'INDUS', 'DIS', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'DIS', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'DIS', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'NOX', 'RAD', 'RM')
# ('LSTAT', 'INDUS', 'NOX', 'RAD', 'TAX')
# ('LSTAT', 'INDUS', 'NOX', 'RAD', 'AGE')
# ('LSTAT', 'INDUS', 'NOX', 'RAD', 'ZN')
# ('LSTAT', 'INDUS', 'NOX', 'RM', 'TAX')
# ('LSTAT', 'INDUS', 'NOX', 'RM', 'AGE')
# ('LSTAT', 'INDUS', 'NOX', 'RM', 'ZN')
# ('LSTAT', 'INDUS', 'NOX', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'NOX', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'NOX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'RAD', 'RM', 'TAX')
# ('LSTAT', 'INDUS', 'RAD', 'RM', 'AGE')
# ('LSTAT', 'INDUS', 'RAD', 'RM', 'ZN')
# ('LSTAT', 'INDUS', 'RAD', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'RAD', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'RAD', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'DIS')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'NOX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'RAD')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'RM')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'TAX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'DIS')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'NOX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'RAD')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'RM')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'TAX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'DIS', 'NOX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'DIS', 'RAD')
# ('LSTAT', 'CRIM', 'PTRATIO', 'DIS', 'RM')
# ('LSTAT', 'CRIM', 'PTRATIO', 'DIS', 'TAX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'DIS', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'DIS', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'NOX', 'RAD')
# ('LSTAT', 'CRIM', 'PTRATIO', 'NOX', 'RM')
# ('LSTAT', 'CRIM', 'PTRATIO', 'NOX', 'TAX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'NOX', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'NOX', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'RAD', 'RM')
# ('LSTAT', 'CRIM', 'PTRATIO', 'RAD', 'TAX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'RAD', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'RAD', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'RM', 'TAX')
# ('LSTAT', 'CRIM', 'PTRATIO', 'RM', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'RM', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'DIS')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'NOX')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'RAD')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'RM')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'TAX')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'AGE')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'DIS', 'NOX')
# ('LSTAT', 'CRIM', 'B', 'DIS', 'RAD')
# ('LSTAT', 'CRIM', 'B', 'DIS', 'RM')
# ('LSTAT', 'CRIM', 'B', 'DIS', 'TAX')
# ('LSTAT', 'CRIM', 'B', 'DIS', 'AGE')
# ('LSTAT', 'CRIM', 'B', 'DIS', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'NOX', 'RAD')
# ('LSTAT', 'CRIM', 'B', 'NOX', 'RM')
# ('LSTAT', 'CRIM', 'B', 'NOX', 'TAX')
# ('LSTAT', 'CRIM', 'B', 'NOX', 'AGE')
# ('LSTAT', 'CRIM', 'B', 'NOX', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'RAD', 'RM')
# ('LSTAT', 'CRIM', 'B', 'RAD', 'TAX')
# ('LSTAT', 'CRIM', 'B', 'RAD', 'AGE')
# ('LSTAT', 'CRIM', 'B', 'RAD', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'RM', 'TAX')
# ('LSTAT', 'CRIM', 'B', 'RM', 'AGE')
# ('LSTAT', 'CRIM', 'B', 'RM', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'B', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'CHAS', 'DIS', 'NOX')
# ('LSTAT', 'CRIM', 'CHAS', 'DIS', 'RAD')
# ('LSTAT', 'CRIM', 'CHAS', 'DIS', 'RM')
# ('LSTAT', 'CRIM', 'CHAS', 'DIS', 'TAX')
# ('LSTAT', 'CRIM', 'CHAS', 'DIS', 'AGE')
# ('LSTAT', 'CRIM', 'CHAS', 'DIS', 'ZN')
# ('LSTAT', 'CRIM', 'CHAS', 'NOX', 'RAD')
# ('LSTAT', 'CRIM', 'CHAS', 'NOX', 'RM')
# ('LSTAT', 'CRIM', 'CHAS', 'NOX', 'TAX')
# ('LSTAT', 'CRIM', 'CHAS', 'NOX', 'AGE')
# ('LSTAT', 'CRIM', 'CHAS', 'NOX', 'ZN')
# ('LSTAT', 'CRIM', 'CHAS', 'RAD', 'RM')
# ('LSTAT', 'CRIM', 'CHAS', 'RAD', 'TAX')
# ('LSTAT', 'CRIM', 'CHAS', 'RAD', 'AGE')
# ('LSTAT', 'CRIM', 'CHAS', 'RAD', 'ZN')
# ('LSTAT', 'CRIM', 'CHAS', 'RM', 'TAX')
# ('LSTAT', 'CRIM', 'CHAS', 'RM', 'AGE')
# ('LSTAT', 'CRIM', 'CHAS', 'RM', 'ZN')
# ('LSTAT', 'CRIM', 'CHAS', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'CHAS', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'CHAS', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'DIS', 'NOX', 'RAD')
# ('LSTAT', 'CRIM', 'DIS', 'NOX', 'RM')
# ('LSTAT', 'CRIM', 'DIS', 'NOX', 'TAX')
# ('LSTAT', 'CRIM', 'DIS', 'NOX', 'AGE')
# ('LSTAT', 'CRIM', 'DIS', 'NOX', 'ZN')
# ('LSTAT', 'CRIM', 'DIS', 'RAD', 'RM')
# ('LSTAT', 'CRIM', 'DIS', 'RAD', 'TAX')
# ('LSTAT', 'CRIM', 'DIS', 'RAD', 'AGE')
# ('LSTAT', 'CRIM', 'DIS', 'RAD', 'ZN')
# ('LSTAT', 'CRIM', 'DIS', 'RM', 'TAX')
# ('LSTAT', 'CRIM', 'DIS', 'RM', 'AGE')
# ('LSTAT', 'CRIM', 'DIS', 'RM', 'ZN')
# ('LSTAT', 'CRIM', 'DIS', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'DIS', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'DIS', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'NOX', 'RAD', 'RM')
# ('LSTAT', 'CRIM', 'NOX', 'RAD', 'TAX')
# ('LSTAT', 'CRIM', 'NOX', 'RAD', 'AGE')
# ('LSTAT', 'CRIM', 'NOX', 'RAD', 'ZN')
# ('LSTAT', 'CRIM', 'NOX', 'RM', 'TAX')
# ('LSTAT', 'CRIM', 'NOX', 'RM', 'AGE')
# ('LSTAT', 'CRIM', 'NOX', 'RM', 'ZN')
# ('LSTAT', 'CRIM', 'NOX', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'NOX', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'NOX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'RAD', 'RM', 'TAX')
# ('LSTAT', 'CRIM', 'RAD', 'RM', 'AGE')
# ('LSTAT', 'CRIM', 'RAD', 'RM', 'ZN')
# ('LSTAT', 'CRIM', 'RAD', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'RAD', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'RAD', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'DIS')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'NOX')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'RAD')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'RM')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'TAX')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'AGE')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'DIS', 'NOX')
# ('LSTAT', 'PTRATIO', 'B', 'DIS', 'RAD')
# ('LSTAT', 'PTRATIO', 'B', 'DIS', 'RM')
# ('LSTAT', 'PTRATIO', 'B', 'DIS', 'TAX')
# ('LSTAT', 'PTRATIO', 'B', 'DIS', 'AGE')
# ('LSTAT', 'PTRATIO', 'B', 'DIS', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'NOX', 'RAD')
# ('LSTAT', 'PTRATIO', 'B', 'NOX', 'RM')
# ('LSTAT', 'PTRATIO', 'B', 'NOX', 'TAX')
# ('LSTAT', 'PTRATIO', 'B', 'NOX', 'AGE')
# ('LSTAT', 'PTRATIO', 'B', 'NOX', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'RAD', 'RM')
# ('LSTAT', 'PTRATIO', 'B', 'RAD', 'TAX')
# ('LSTAT', 'PTRATIO', 'B', 'RAD', 'AGE')
# ('LSTAT', 'PTRATIO', 'B', 'RAD', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'RM', 'TAX')
# ('LSTAT', 'PTRATIO', 'B', 'RM', 'AGE')
# ('LSTAT', 'PTRATIO', 'B', 'RM', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'TAX', 'AGE')
# ('LSTAT', 'PTRATIO', 'B', 'TAX', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'CHAS', 'DIS', 'NOX')
# ('LSTAT', 'PTRATIO', 'CHAS', 'DIS', 'RAD')
# ('LSTAT', 'PTRATIO', 'CHAS', 'DIS', 'RM')
# ('LSTAT', 'PTRATIO', 'CHAS', 'DIS', 'TAX')
# ('LSTAT', 'PTRATIO', 'CHAS', 'DIS', 'AGE')
# ('LSTAT', 'PTRATIO', 'CHAS', 'DIS', 'ZN')
# ('LSTAT', 'PTRATIO', 'CHAS', 'NOX', 'RAD')
# ('LSTAT', 'PTRATIO', 'CHAS', 'NOX', 'RM')
# ('LSTAT', 'PTRATIO', 'CHAS', 'NOX', 'TAX')
# ('LSTAT', 'PTRATIO', 'CHAS', 'NOX', 'AGE')
# ('LSTAT', 'PTRATIO', 'CHAS', 'NOX', 'ZN')
# ('LSTAT', 'PTRATIO', 'CHAS', 'RAD', 'RM')
# ('LSTAT', 'PTRATIO', 'CHAS', 'RAD', 'TAX')
# ('LSTAT', 'PTRATIO', 'CHAS', 'RAD', 'AGE')
# ('LSTAT', 'PTRATIO', 'CHAS', 'RAD', 'ZN')
# ('LSTAT', 'PTRATIO', 'CHAS', 'RM', 'TAX')
# ('LSTAT', 'PTRATIO', 'CHAS', 'RM', 'AGE')
# ('LSTAT', 'PTRATIO', 'CHAS', 'RM', 'ZN')
# ('LSTAT', 'PTRATIO', 'CHAS', 'TAX', 'AGE')
# ('LSTAT', 'PTRATIO', 'CHAS', 'TAX', 'ZN')
# ('LSTAT', 'PTRATIO', 'CHAS', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'DIS', 'NOX', 'RAD')
# ('LSTAT', 'PTRATIO', 'DIS', 'NOX', 'RM')
# ('LSTAT', 'PTRATIO', 'DIS', 'NOX', 'TAX')
# ('LSTAT', 'PTRATIO', 'DIS', 'NOX', 'AGE')
# ('LSTAT', 'PTRATIO', 'DIS', 'NOX', 'ZN')
# ('LSTAT', 'PTRATIO', 'DIS', 'RAD', 'RM')
# ('LSTAT', 'PTRATIO', 'DIS', 'RAD', 'TAX')
# ('LSTAT', 'PTRATIO', 'DIS', 'RAD', 'AGE')
# ('LSTAT', 'PTRATIO', 'DIS', 'RAD', 'ZN')
# ('LSTAT', 'PTRATIO', 'DIS', 'RM', 'TAX')
# ('LSTAT', 'PTRATIO', 'DIS', 'RM', 'AGE')
# ('LSTAT', 'PTRATIO', 'DIS', 'RM', 'ZN')
# ('LSTAT', 'PTRATIO', 'DIS', 'TAX', 'AGE')
# ('LSTAT', 'PTRATIO', 'DIS', 'TAX', 'ZN')
# ('LSTAT', 'PTRATIO', 'DIS', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'NOX', 'RAD', 'RM')
# ('LSTAT', 'PTRATIO', 'NOX', 'RAD', 'TAX')
# ('LSTAT', 'PTRATIO', 'NOX', 'RAD', 'AGE')
# ('LSTAT', 'PTRATIO', 'NOX', 'RAD', 'ZN')
# ('LSTAT', 'PTRATIO', 'NOX', 'RM', 'TAX')
# ('LSTAT', 'PTRATIO', 'NOX', 'RM', 'AGE')
# ('LSTAT', 'PTRATIO', 'NOX', 'RM', 'ZN')
# ('LSTAT', 'PTRATIO', 'NOX', 'TAX', 'AGE')
# ('LSTAT', 'PTRATIO', 'NOX', 'TAX', 'ZN')
# ('LSTAT', 'PTRATIO', 'NOX', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'RAD', 'RM', 'TAX')
# ('LSTAT', 'PTRATIO', 'RAD', 'RM', 'AGE')
# ('LSTAT', 'PTRATIO', 'RAD', 'RM', 'ZN')
# ('LSTAT', 'PTRATIO', 'RAD', 'TAX', 'AGE')
# ('LSTAT', 'PTRATIO', 'RAD', 'TAX', 'ZN')
# ('LSTAT', 'PTRATIO', 'RAD', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'PTRATIO', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'PTRATIO', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'B', 'CHAS', 'DIS', 'NOX')
# ('LSTAT', 'B', 'CHAS', 'DIS', 'RAD')
# ('LSTAT', 'B', 'CHAS', 'DIS', 'RM')
# ('LSTAT', 'B', 'CHAS', 'DIS', 'TAX')
# ('LSTAT', 'B', 'CHAS', 'DIS', 'AGE')
# ('LSTAT', 'B', 'CHAS', 'DIS', 'ZN')
# ('LSTAT', 'B', 'CHAS', 'NOX', 'RAD')
# ('LSTAT', 'B', 'CHAS', 'NOX', 'RM')
# ('LSTAT', 'B', 'CHAS', 'NOX', 'TAX')
# ('LSTAT', 'B', 'CHAS', 'NOX', 'AGE')
# ('LSTAT', 'B', 'CHAS', 'NOX', 'ZN')
# ('LSTAT', 'B', 'CHAS', 'RAD', 'RM')
# ('LSTAT', 'B', 'CHAS', 'RAD', 'TAX')
# ('LSTAT', 'B', 'CHAS', 'RAD', 'AGE')
# ('LSTAT', 'B', 'CHAS', 'RAD', 'ZN')
# ('LSTAT', 'B', 'CHAS', 'RM', 'TAX')
# ('LSTAT', 'B', 'CHAS', 'RM', 'AGE')
# ('LSTAT', 'B', 'CHAS', 'RM', 'ZN')
# ('LSTAT', 'B', 'CHAS', 'TAX', 'AGE')
# ('LSTAT', 'B', 'CHAS', 'TAX', 'ZN')
# ('LSTAT', 'B', 'CHAS', 'AGE', 'ZN')
# ('LSTAT', 'B', 'DIS', 'NOX', 'RAD')
# ('LSTAT', 'B', 'DIS', 'NOX', 'RM')
# ('LSTAT', 'B', 'DIS', 'NOX', 'TAX')
# ('LSTAT', 'B', 'DIS', 'NOX', 'AGE')
# ('LSTAT', 'B', 'DIS', 'NOX', 'ZN')
# ('LSTAT', 'B', 'DIS', 'RAD', 'RM')
# ('LSTAT', 'B', 'DIS', 'RAD', 'TAX')
# ('LSTAT', 'B', 'DIS', 'RAD', 'AGE')
# ('LSTAT', 'B', 'DIS', 'RAD', 'ZN')
# ('LSTAT', 'B', 'DIS', 'RM', 'TAX')
# ('LSTAT', 'B', 'DIS', 'RM', 'AGE')
# ('LSTAT', 'B', 'DIS', 'RM', 'ZN')
# ('LSTAT', 'B', 'DIS', 'TAX', 'AGE')
# ('LSTAT', 'B', 'DIS', 'TAX', 'ZN')
# ('LSTAT', 'B', 'DIS', 'AGE', 'ZN')
# ('LSTAT', 'B', 'NOX', 'RAD', 'RM')
# ('LSTAT', 'B', 'NOX', 'RAD', 'TAX')
# ('LSTAT', 'B', 'NOX', 'RAD', 'AGE')
# ('LSTAT', 'B', 'NOX', 'RAD', 'ZN')
# ('LSTAT', 'B', 'NOX', 'RM', 'TAX')
# ('LSTAT', 'B', 'NOX', 'RM', 'AGE')
# ('LSTAT', 'B', 'NOX', 'RM', 'ZN')
# ('LSTAT', 'B', 'NOX', 'TAX', 'AGE')
# ('LSTAT', 'B', 'NOX', 'TAX', 'ZN')
# ('LSTAT', 'B', 'NOX', 'AGE', 'ZN')
# ('LSTAT', 'B', 'RAD', 'RM', 'TAX')
# ('LSTAT', 'B', 'RAD', 'RM', 'AGE')
# ('LSTAT', 'B', 'RAD', 'RM', 'ZN')
# ('LSTAT', 'B', 'RAD', 'TAX', 'AGE')
# ('LSTAT', 'B', 'RAD', 'TAX', 'ZN')
# ('LSTAT', 'B', 'RAD', 'AGE', 'ZN')
# ('LSTAT', 'B', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'B', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'B', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'B', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CHAS', 'DIS', 'NOX', 'RAD')
# ('LSTAT', 'CHAS', 'DIS', 'NOX', 'RM')
# ('LSTAT', 'CHAS', 'DIS', 'NOX', 'TAX')
# ('LSTAT', 'CHAS', 'DIS', 'NOX', 'AGE')
# ('LSTAT', 'CHAS', 'DIS', 'NOX', 'ZN')
# ('LSTAT', 'CHAS', 'DIS', 'RAD', 'RM')
# ('LSTAT', 'CHAS', 'DIS', 'RAD', 'TAX')
# ('LSTAT', 'CHAS', 'DIS', 'RAD', 'AGE')
# ('LSTAT', 'CHAS', 'DIS', 'RAD', 'ZN')
# ('LSTAT', 'CHAS', 'DIS', 'RM', 'TAX')
# ('LSTAT', 'CHAS', 'DIS', 'RM', 'AGE')
# ('LSTAT', 'CHAS', 'DIS', 'RM', 'ZN')
# ('LSTAT', 'CHAS', 'DIS', 'TAX', 'AGE')
# ('LSTAT', 'CHAS', 'DIS', 'TAX', 'ZN')
# ('LSTAT', 'CHAS', 'DIS', 'AGE', 'ZN')
# ('LSTAT', 'CHAS', 'NOX', 'RAD', 'RM')
# ('LSTAT', 'CHAS', 'NOX', 'RAD', 'TAX')
# ('LSTAT', 'CHAS', 'NOX', 'RAD', 'AGE')
# ('LSTAT', 'CHAS', 'NOX', 'RAD', 'ZN')
# ('LSTAT', 'CHAS', 'NOX', 'RM', 'TAX')
# ('LSTAT', 'CHAS', 'NOX', 'RM', 'AGE')
# ('LSTAT', 'CHAS', 'NOX', 'RM', 'ZN')
# ('LSTAT', 'CHAS', 'NOX', 'TAX', 'AGE')
# ('LSTAT', 'CHAS', 'NOX', 'TAX', 'ZN')
# ('LSTAT', 'CHAS', 'NOX', 'AGE', 'ZN')
# ('LSTAT', 'CHAS', 'RAD', 'RM', 'TAX')
# ('LSTAT', 'CHAS', 'RAD', 'RM', 'AGE')
# ...
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')
# ('LSTAT', 'INDUS', 'CRIM', 'PTRATIO', 'B', 'CHAS', 'DIS', 'NOX', 'RAD', 'RM', 'TAX', 'AGE', 'ZN')

# %% [markdown]
# ##### lin 1d powerset

# %%
from itertools import chain, combinations
i = set(list(X.columns))
for p in chain.from_iterable(combinations(i, r) for r in range(len(i)+1)):

    if len(p) == 0:
        continue
    else:
        x_train_1d_2 = X_train.loc[:, p].as_matrix()
        lin_1d_2.fit(x_train_1d_2, y_train)
        x_test_1d_2 = X_test.loc[:, list(p)].as_matrix()
        score_1d_2 = lin_1d_2.score(x_test_1d_2, y_test)

        if score_1d_2 >= 0.6:
            print('{0}:{1}'.format(score_1d_2, p))
# Out:
# 0.6002388637827509:('LSTAT', 'B', 'CHAS', 'DIS', 'RM')
# 0.6034628831496074:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM')
# 0.6026671957203775:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'AGE')
# 0.6028721939887381:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'ZN')
# 0.6052817454567311:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE')
# 0.6088215639681172:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'ZN')
# 0.6058009537387953:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'AGE', 'ZN')
# 0.609504259973593:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE', 'ZN')

# %% [markdown]
# ##### lin 2d powerset

# %%
from itertools import chain, combinations
i = set(list(X.columns))
for p in chain.from_iterable(combinations(i, r) for r in range(len(i)+1)):

    if len(p) == 0:
        continue
    else:
        x_train_2d = X_train.loc[:, p].as_matrix()
        lin_2d.fit(x_train_2d, y_train)
        x_test_2d = X_test.loc[:, p].as_matrix()
        score_2d = lin_2d.score(x_test_2d, y_test)

        if score_2d >= 0.6:
            print('{0}:{1}'.format(score_2d, p))
# Out:
# 0.6002388637827509:('LSTAT', 'B', 'CHAS', 'DIS', 'RM')
# 0.6034628831496074:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM')
# 0.6026671957203775:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'AGE')
# 0.6028721939887381:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'ZN')
# 0.6052817454567311:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE')
# 0.6088215639681172:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'ZN')
# 0.6058009537387953:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'AGE', 'ZN')
# 0.6095042599735929:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE', 'ZN')

# %% [markdown]
# ##### lin 3d powerset

# %%
from itertools import chain, combinations
i = set(list(X.columns))
for p in chain.from_iterable(combinations(i, r) for r in range(len(i)+1)):

    if len(p) == 0:
        continue
    else:
        x_train_3d = X_train.loc[:, list(p)].as_matrix()
        lin_3d.fit(x_train_3d, y_train)
        x_test_3d = X_test.loc[:, list(p)].as_matrix()
        score_3d = lin_3d.score(x_test_3d, y_test)

        if score_3d >= 0.6:
            print('{0}:{1}'.format(score_3d, p))
# Out:
# 0.6002388637827509:('LSTAT', 'B', 'CHAS', 'DIS', 'RM')
# 0.6034628831496074:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM')
# 0.6026671957203775:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'AGE')
# 0.6028721939887381:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'ZN')
# 0.6052817454567311:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE')
# 0.6088215639681172:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'ZN')
# 0.6058009537387953:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'AGE', 'ZN')
# 0.6095042599735929:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE', 'ZN')

# %% [markdown]
# ##### lin 4d powerset

# %%
from itertools import chain, combinations
i = set(list(X.columns))
for p in chain.from_iterable(combinations(i, r) for r in range(len(i)+1)):

    if len(p) == 0:
        continue
    else:
        x_train_4d = X_train.loc[:, p].as_matrix()
        lin_4d.fit(x_train_4d, y_train)
        x_test_4d = X_test.loc[:, p].as_matrix()
        score_4d = lin_4d.score(x_test_4d, y_test)

        if score_4d >= 0.6:
            print('{0}:{1}'.format(score_4d, p))
# Out:
# 0.6002388637827509:('LSTAT', 'B', 'CHAS', 'DIS', 'RM')
# 0.6034628831496074:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM')
# 0.6026671957203775:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'AGE')
# 0.6028721939887381:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'ZN')
# 0.6052817454567311:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE')
# 0.6088215639681172:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'ZN')
# 0.6058009537387953:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'AGE', 'ZN')
# 0.609504259973593:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE', 'ZN')

# %% [markdown]
# ##### 5d powerset

# %%
from itertools import chain, combinations
i = set(list(X.columns))
for p in chain.from_iterable(combinations(i, r) for r in range(len(i)+1)):

    if len(p) == 0:
        continue
    else:
        x_train_5d = X_train.loc[:, p].as_matrix()
        lin_5d.fit(x_train_5d, y_train)
        x_test_5d = X_test.loc[:, p].as_matrix()
        score_5d = lin_5d.score(x_test_5d, y_test)

        if score_5d >= 0.6:
            print('{0}:{1}'.format(score_5d, p))
# Out:
# 0.6002388637827509:('LSTAT', 'B', 'CHAS', 'DIS', 'RM')
# 0.6034628831496074:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM')
# 0.6026671957203775:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'AGE')
# 0.6028721939887381:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'ZN')
# 0.6052817454567311:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE')
# 0.6088215639681172:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'ZN')
# 0.6058009537387953:('LSTAT', 'B', 'CHAS', 'DIS', 'RM', 'AGE', 'ZN')
# 0.6095042599735929:('LSTAT', 'B', 'CHAS', 'DIS', 'NOX', 'RM', 'AGE', 'ZN')

# %% [markdown]
# ##### 正則化

# %%
degree_=PolynomialFeatures(degree=5)
x_=degree_.fit_transform(x[:,None])
lin_ = Ridge(normalize=True,alpha=0.0001)
lin_.fit(x_,y)
print(lin_.coef_)

# %%
from itertools import chain, combinations
from sklearn.linear_model import Ridge
i = set(list(X.columns))
degree_ =PolynomialFeatures(degree=5)
for p in chain.from_iterable(combinations(i, r) for r in range(len(i)+1)):

    if len(p) == 0:
        continue
    else:

        x_train_5d_r_tmp = X_train.loc[:, p].as_matrix()
        x_train_5d_r = degree_.fit_transform(x_train_5d_r_tmp)

        lin_r = Ridge(normalize=True,alpha=0.0001)
        lin_r.fit(x_train_5d_r,y_train)
        
        x_test_5d_r = X_test.loc[:, p].as_matrix()
        score_5d_r = lin_r.score(x_test_5d_r, y_test)

        if score_5d_r >= 0.6:
            print('{0}:{1}'.format(score_5d_r, p))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-332-cee09138b75d> in <module>()
#      16
#      17         x_test_5d_r = X_test.loc[:, p].as_matrix()
# ---> 18         score_5d_r = lin_r.score(x_test_5d_r, y_test)
#      19
#      20         if score_5d_r >= 0.6:
#
# ~/lab/March/lib/python3.6/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     385
#     386         from .metrics import r2_score
# --> 387         return r2_score(y, self.predict(X), sample_weight=sample_weight,
#     388                         multioutput='variance_weighted')
#     389
#
# ~/lab/March/lib/python3.6/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/lab/March/lib/python3.6/site-packages/sklearn/linear_model/base.py in _decision_function(self, X)
#     239         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     240         return safe_sparse_dot(X, self.coef_.T,
# --> 241                                dense_output=True) + self.intercept_
#     242
#     243     def predict(self, X):
#
# ~/lab/March/lib/python3.6/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     138         return ret
#     139     else:
# --> 140         return np.dot(a, b)
#     141
#     142
#
# ValueError: shapes (102,1) and (6,1) not aligned: 1 (dim 1) != 6 (dim 0)

# %%
x_test_5d_r.shape
# Out:
# (102, 1)

# %%
y_test.shape
# Out:
# (102, 1)

# %% [markdown]
# # 重回帰について記述せよ

# %% [markdown]
# - 重回帰は複数のxとして、複数の特徴量を扱う回帰。
#     - 例）新幹線の利用者。x1:GDP成長率、x2：高速道路の通行料、x3：航空運賃,y:新幹線の利用者数
