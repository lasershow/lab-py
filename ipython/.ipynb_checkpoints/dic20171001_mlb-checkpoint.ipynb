# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pitching_df = pd.read_csv("testdata/core/Pitching.csv")
salary_df = pd.read_csv("testdata/core/Salaries.csv")

# %% [markdown]
# # データセット準備

# %%
#df = pd.merge(pitching_df,salary_df,on=['yearID', 'teamID', 'playerID'])
df = pd.merge(pitching_df,salary_df,on=['yearID', 'teamID', 'lgID', 'playerID'], how='outer')
#df = pd.merge(pitching_df,salary_df,on=['yearID', 'teamID', 'playerID'], how='outer')
#df = pd.merge(pitching_df,salary_df,on=['yearID', 'teamID', 'lgID', 'playerID'])

# %%
pitching_df[['yearID','teamID','lgID','playerID']].isnull().sum()

# %%
salary_df[['yearID','teamID','lgID','playerID']].isnull().sum()

# %%
df.count()

# %%
df['salary'].isnull().sum()
# Out:
# 33166

# %%
#how='inner'
#salary      11797
#how='outer'
#salary      26431   =====>母数が多い方が良い。
#how='inner' minus lgID
#salary      11799

# %%
df_sal_nonan = df.dropna(subset=["salary"]).reset_index(drop=True)

# %%
df_sal_nonan.isnull().sum()
#df_sal_nonan
# Out:
# playerID        0
# yearID          0
# stint       14634
# teamID          0
# lgID            0
# W           14634
# L           14634
# G           14634
# GS          14634
# CG          14634
# SHO         14634
# SV          14634
# IPouts      14634
# H           14634
# ER          14634
# HR          14634
# BB          14634
# SO          14634
# BAOpp       15095
# ERA         14639
# IBB         14634
# WP          14634
# HBP         14634
# BK          14634
# BFP         14634
# GF          14634
# R           14634
# SH          19950
# SF          19950
# GIDP        19950
# salary          0
# dtype: int64

# %%
df_sal_nonan.columns.all
# Out:
# <bound method Index._add_logical_methods.<locals>._make_logical_function.<locals>.logical_func of Index(['playerID', 'yearID', 'stint', 'teamID', 'lgID', 'W', 'L', 'G', 'GS',
#        'CG', 'SHO', 'SV', 'IPouts', 'H', 'ER', 'HR', 'BB', 'SO', 'BAOpp',
#        'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP', 'GF', 'R', 'SH', 'SF', 'GIDP',
#        'salary'],
#       dtype='object')>

# %% [markdown]
# # データのチェック

# %% [markdown]
# yearID: Higher salary in the recent year

# %%
df_sal_nonan[["salary", "yearID"]].groupby(['yearID'], as_index=False).mean().sort_values(by='salary', ascending=False).head(8)
# Out:
#     yearID        salary
# 31    2016  4.396410e+06
# 30    2015  4.301276e+06
# 29    2014  3.980446e+06
# 28    2013  3.723344e+06
# 27    2012  3.458421e+06
# 26    2011  3.318838e+06
# 25    2010  3.278747e+06
# 24    2009  3.277647e+06

# %% [markdown]
# stint: not related

# %%
df_sal_nonan[["salary", "stint"]].groupby(['stint'], as_index=False).mean().sort_values(by='salary', ascending=False)
# Out:
#    stint        salary
# 3    4.0  1.916667e+06
# 0    1.0  1.906287e+06
# 1    2.0  8.810014e+05
# 2    3.0  4.655714e+05

# %% [markdown]
# teamID: NYY is the doubled salary of salary in 75% percentiles.

# %%
len(df_sal_nonan.teamID.unique())
# Out:
# 46

# %%
df_sal_nonan[["salary", "teamID"]].groupby(['teamID'], as_index=False).mean().sort_values(by='salary', ascending=False).head(15)
# Out:
#    teamID        salary
# 29    NYY  7.689579e+06
# 36    SFG  6.890151e+06
# 19    LAD  6.322525e+06
# 45    WSN  5.448179e+06
# 7     CHC  5.312678e+06
# 27    NYM  4.958857e+06
# 39    STL  4.614629e+06
# 17    KCR  4.534039e+06
# 9     CHW  4.519947e+06
# 18    LAA  4.291454e+06
# 26    NYA  3.850079e+06
# 34    SDP  3.756475e+06
# 4     BOS  2.968591e+06
# 44    WAS  2.730243e+06
# 20    LAN  2.661127e+06

# %%
df_sal_nonan[["salary", "teamID"]].groupby(['teamID'], as_index=False).mean().sort_values(by='salary', ascending=False).describe()
# Out:
#              salary
# count  4.600000e+01
# mean   2.776800e+06
# std    1.641747e+06
# min    6.132436e+05
# 25%    1.765734e+06
# 50%    2.233278e+06
# 75%    3.559504e+06
# max    7.689579e+06

# %% [markdown]
# lgID: Not related since datas are similar

# %%
df_sal_nonan[["salary", "lgID"]].groupby(['lgID'], as_index=False).mean().sort_values(by='salary', ascending=False).head(15)
# Out:
#   lgID        salary
# 0   AL  2.128432e+06
# 1   NL  2.044299e+06

# %% [markdown]
# W: Most wins ranked at 25. There is loose correlation between salary and W. It has tendency salary is slightly higher if W is over 10.

# %%
df_sal_nonan[["salary", "W"]].groupby(['W'], as_index=False).mean().sort_values(by='salary', ascending=False)
# Out:
#        W        salary
# 24  24.0  5.723333e+06
# 19  19.0  5.085511e+06
# 21  21.0  5.049713e+06
# 17  17.0  4.496803e+06
# 20  20.0  4.494361e+06
# 16  16.0  4.378319e+06
# 22  22.0  4.190567e+06
# 23  23.0  4.039167e+06
# 15  15.0  3.956281e+06
# 13  13.0  3.581041e+06
# 18  18.0  3.542739e+06
# 14  14.0  3.452220e+06
# 11  11.0  2.870553e+06
# 12  12.0  2.584164e+06
# 9    9.0  2.540634e+06
# 10  10.0  2.456472e+06
# 8    8.0  2.316213e+06
# 6    6.0  2.001373e+06
# 7    7.0  1.981109e+06
# 5    5.0  1.747015e+06
# 4    4.0  1.625374e+06
# 3    3.0  1.466500e+06
# 2    2.0  1.427303e+06
# 1    1.0  1.336820e+06
# 25  27.0  1.133334e+06
# 0    0.0  1.036660e+06

# %%
df_sal_nonan[["salary", "W"]].groupby(['W'], as_index=False).mean().sort_values(by='salary', ascending=False).describe()
# Out:
#                W        salary
# count  26.000000  2.600000e+01
# mean   12.576923  3.019753e+06
# std     7.788058  1.388061e+06
# min     0.000000  1.036660e+06
# 25%     6.250000  1.805538e+06
# 50%    12.500000  2.727358e+06
# 75%    18.750000  4.152717e+06
# max    27.000000  5.723333e+06

# %% [markdown]
# L: No relation since L is randomly ranked.

# %%
df_sal_nonan[["salary", "L"]].groupby(['L'], as_index=False).mean().sort_values(by='salary', ascending=False)
# Out:
#        L        salary
# 13  13.0  3.371370e+06
# 14  14.0  3.261926e+06
# 18  18.0  3.045528e+06
# 9    9.0  3.008971e+06
# 15  15.0  2.963031e+06
# 8    8.0  2.884996e+06
# 10  10.0  2.796036e+06
# 12  12.0  2.752695e+06
# 11  11.0  2.739389e+06
# 7    7.0  2.613283e+06
# 17  17.0  2.599530e+06
# 16  16.0  2.115505e+06
# 6    6.0  2.036219e+06
# 5    5.0  1.914637e+06
# 4    4.0  1.815039e+06
# 3    3.0  1.520180e+06
# 2    2.0  1.359219e+06
# 1    1.0  1.127316e+06
# 0    0.0  9.029439e+05
# 19  19.0  8.651667e+05
# 20  21.0  3.090000e+05

# %% [markdown]
# G:  Games is not related

# %%
df_sal_nonan[["salary", "G"]].groupby(['G'], as_index=False).mean().sort_values(by='salary', ascending=False)
# Out:
#        G        salary
# 32  33.0  3.305843e+06
# 33  34.0  3.123988e+06
# 31  32.0  3.042416e+06
# 20  21.0  2.901644e+06
# 90  92.0  2.900000e+06
# 29  30.0  2.794496e+06
# 30  31.0  2.685651e+06
# 34  35.0  2.475981e+06
# 19  20.0  2.387894e+06
# 28  29.0  2.255611e+06
# 17  18.0  2.223133e+06
# 24  25.0  2.221185e+06
# 27  28.0  2.218583e+06
# 25  26.0  2.185445e+06
# 60  61.0  2.099462e+06
# 22  23.0  2.090837e+06
# 18  19.0  2.043444e+06
# 26  27.0  2.034420e+06
# 21  22.0  2.031579e+06
# 12  13.0  1.985577e+06
# 65  66.0  1.982907e+06
# 59  60.0  1.973863e+06
# 23  24.0  1.966724e+06
# 83  84.0  1.885417e+06
# 63  64.0  1.862392e+06
# 35  36.0  1.792286e+06
# 67  68.0  1.739149e+06
# 66  67.0  1.705385e+06
# 61  62.0  1.701484e+06
# 62  63.0  1.696099e+06
# ..   ...           ...
# 51  52.0  1.232396e+06
# 52  53.0  1.213513e+06
# 49  50.0  1.206555e+06
# 1    2.0  1.203293e+06
# 42  43.0  1.196665e+06
# 58  59.0  1.181444e+06
# 80  81.0  1.173787e+06
# 40  41.0  1.167873e+06
# 36  37.0  1.166889e+06
# 3    4.0  1.160483e+06
# 38  39.0  1.121177e+06
# 88  89.0  1.118933e+06
# 4    5.0  1.103502e+06
# 37  38.0  1.103342e+06
# 46  47.0  1.087462e+06
# 9   10.0  1.076409e+06
# 54  55.0  1.076207e+06
# 45  46.0  1.069065e+06
# 41  42.0  1.068034e+06
# 43  44.0  1.029130e+06
# 50  51.0  1.021453e+06
# 2    3.0  1.008926e+06
# 55  56.0  9.698804e+05
# 89  90.0  9.250000e+05
# 48  49.0  9.221725e+05
# 81  82.0  8.428750e+05
# 82  83.0  7.431396e+05
# 87  88.0  6.181250e+05
# 84  85.0  5.402500e+05
# 86  87.0  2.525000e+05
#
# [92 rows x 2 columns]

# %% [markdown]
# GS: Games Started is not related since around 30 ranked at the last

# %%
df_sal_nonan[["salary",'GS']].groupby(['GS'], as_index=False).mean().sort_values(by='salary', ascending=False)
# Out:
#       GS        salary
# 34  34.0  4.017841e+06
# 33  33.0  3.867517e+06
# 21  21.0  3.649101e+06
# 32  32.0  3.642111e+06
# 30  30.0  3.473978e+06
# 35  35.0  3.463631e+06
# 20  20.0  3.273527e+06
# 31  31.0  3.254913e+06
# 18  18.0  3.067798e+06
# 29  29.0  2.984506e+06
# 25  25.0  2.951923e+06
# 22  22.0  2.911067e+06
# 26  26.0  2.739947e+06
# 28  28.0  2.603445e+06
# 27  27.0  2.552218e+06
# 24  24.0  2.519207e+06
# 23  23.0  2.485478e+06
# 19  19.0  2.450514e+06
# 36  36.0  2.265565e+06
# 13  13.0  2.054059e+06
# 16  16.0  2.025121e+06
# 17  17.0  1.938355e+06
# 12  12.0  1.735001e+06
# 11  11.0  1.697916e+06
# 10  10.0  1.678805e+06
# 15  15.0  1.632469e+06
# 9    9.0  1.525840e+06
# 8    8.0  1.480849e+06
# 7    7.0  1.458156e+06
# 6    6.0  1.315221e+06
# 0    0.0  1.288794e+06
# 5    5.0  1.259531e+06
# 14  14.0  1.206215e+06
# 3    3.0  1.191676e+06
# 4    4.0  1.160567e+06
# 2    2.0  8.521471e+05
# 1    1.0  7.768441e+05
# 37  37.0  7.669801e+05
# 38  38.0  6.966667e+05
# 39  39.0  4.366667e+05

# %%
df_sal_nonan[["salary",'GS']].groupby(['GS'], as_index=False).mean().sort_values(by='salary', ascending=False).describe()
# Out:
#               GS        salary
# count  40.000000  4.000000e+01
# mean   19.500000  2.158804e+06
# std    11.690452  9.935949e+05
# min     0.000000  4.366667e+05
# 25%     9.750000  1.308614e+06
# 50%    19.500000  2.039590e+06
# 75%    29.250000  2.960069e+06
# max    39.000000  4.017841e+06

# %% [markdown]
# * * * * * * * * * * * * *

# %% [markdown]
# * * * * * * * * * * * * *

# %%
df_sal_nonan.iloc[:3,:20]

# %%
df_sal_nonan.iloc[:3,21:28]
# Out:
#     WP  HBP   BK     BFP    GF      R  SH
# 0  2.0  3.0  0.0   370.0  26.0   35.0 NaN
# 1  0.0  3.0  0.0   246.0  21.0   27.0 NaN
# 2  9.0  6.0  0.0  1090.0   0.0  105.0 NaN

# %%
pitching_df.iloc[:,:13].describe()
# Out:
#              yearID         stint             W             L             G  \
# count  44963.000000  44963.000000  44963.000000  44963.000000  44963.000000
# mean    1968.670062      1.079643      4.715744      4.715722     23.681761
# std       37.569499      0.284834      5.813410      4.988846     18.493488
# min     1871.000000      1.000000      0.000000      0.000000      1.000000
# 25%     1941.000000      1.000000      0.000000      1.000000      7.000000
# 50%     1978.000000      1.000000      2.000000      3.000000     21.000000
# 75%     2001.000000      1.000000      7.000000      8.000000     35.000000
# max     2016.000000      4.000000     59.000000     48.000000    106.000000
#
#                  GS            CG           SHO            SV        IPouts
# count  44963.000000  44963.000000  44963.000000  44963.000000  44963.000000
# mean       9.485488      3.151035      0.448591      1.504793    253.872139
# std       12.283920      7.081844      1.109742      4.991518    257.330446
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000     49.000000
# 50%        3.000000      0.000000      0.000000      0.000000    167.000000
# 75%       17.000000      3.000000      0.000000      1.000000    393.000000
# max       75.000000     75.000000     16.000000     62.000000   2040.000000

# %%
pitching_df.iloc[:,14:23].describe()
# Out:
#                  ER            HR            BB            SO         BAOpp  \
# count  44963.000000  44963.000000  44963.000000  44963.000000  43437.000000
# mean      36.103863      6.434201     29.905300     46.500856      0.319920
# std       33.431186      6.988237     28.172268     49.345046      0.710482
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        9.000000      1.000000      8.000000      8.000000      0.236000
# 50%       25.000000      4.000000     21.000000     31.000000      0.260000
# 75%       58.000000      9.000000     45.000000     68.000000      0.298000
# max      291.000000     50.000000    289.000000    513.000000      9.990000
#
#                 ERA           IBB            WP           HBP
# count  44874.000000  30388.000000  44830.000000  44405.000000
# mean       5.073269      2.411379      2.528575      2.266096
# std        5.318781      2.772648      3.425706      2.998881
# min        0.000000      0.000000      0.000000      0.000000
# 25%        3.150000      0.000000      0.000000      0.000000
# 50%        4.140000      2.000000      1.000000      1.000000
# 75%        5.510000      4.000000      4.000000      3.000000
# max      189.000000     23.000000     63.000000     41.000000

# %%
pitching_df.iloc[:,24:28].describe()
# Out:
#                 BFP            GF             R            SH
# count  44724.000000  44830.000000  44963.000000  12063.000000
# mean     343.312181      6.345260     43.021773      2.141922
# std      348.758261      9.993949     43.245812      2.710191
# min        0.000000      0.000000      0.000000      0.000000
# 25%       64.000000      0.000000     11.000000      0.000000
# 50%      227.000000      3.000000     28.000000      1.000000
# 75%      535.000000      8.000000     67.000000      3.000000
# max     2906.000000     84.000000    519.000000     21.000000

# %%
pitching_df.describe(include=['O'])
# Out:
#          playerID teamID   lgID
# count       44963  44963  44832
# unique       9302    149      6
# top     newsobo01    PHI     NL
# freq           29   2117  22823

# %%
pitching_df.lgID.unique()
# Out:
# array([nan, 'NL', 'AA', 'UA', 'PL', 'AL', 'FL'], dtype=object)

# %%
pitching_df.loc[:,"lgID"].isnull().any()
# Out:
# True

# %%
salary_df.describe()
# Out:
#              yearID        salary
# count  26428.000000  2.642800e+04
# mean    2000.878727  2.085634e+06
# std        8.909314  3.455348e+06
# min     1985.000000  0.000000e+00
# 25%     1994.000000  2.947020e+05
# 50%     2001.000000  5.500000e+05
# 75%     2009.000000  2.350000e+06
# max     2016.000000  3.300000e+07

# %%
salary_df.describe(include=['O'])
# Out:
#        teamID   lgID   playerID
# count   26428  26428      26428
# unique     46      2       5155
# top       CLE     NL  moyerja01
# freq      949  13469         25

# %%
pitching_df.count()
# Out:
# playerID    44963
# yearID      44963
# stint       44963
# teamID      44963
# lgID        44832
# W           44963
# L           44963
# G           44963
# GS          44963
# CG          44963
# SHO         44963
# SV          44963
# IPouts      44963
# H           44963
# ER          44963
# HR          44963
# BB          44963
# SO          44963
# BAOpp       43437
# ERA         44874
# IBB         30388
# WP          44830
# HBP         44405
# BK          44963
# BFP         44724
# GF          44830
# R           44963
# SH          12063
# SF          12063
# GIDP        12061
# dtype: int64

# %%
salary_df.count()
# Out:
# yearID      26428
# teamID      26428
# lgID        26428
# playerID    26428
# salary      26428
# dtype: int64

# %%
df.count()
# Out:
# playerID    11797
# yearID      11797
# stint       11797
# teamID      11797
# lgID        11797
# W           11797
# L           11797
# G           11797
# GS          11797
# CG          11797
# SHO         11797
# SV          11797
# IPouts      11797
# H           11797
# ER          11797
# HR          11797
# BB          11797
# SO          11797
# BAOpp       11336
# ERA         11792
# IBB         11797
# WP          11797
# HBP         11797
# BK          11797
# BFP         11797
# GF          11797
# R           11797
# SH           6481
# SF           6481
# GIDP         6481
# salary      11797
# dtype: int64

# %%
df.head()
# Out:
#     playerID  yearID  stint teamID lgID   W   L   G  GS  CG   ...     WP  HBP  \
# 0  ackerji01    1985      1    TOR   AL   7   2  61   0   0   ...    2.0  3.0
# 1  agostju01    1985      1    CHA   AL   4   3  54   0   0   ...    0.0  3.0
# 2  alexado01    1985      1    TOR   AL  17  10  36  36   6   ...    9.0  6.0
# 3  allenne01    1985      1    SLN   NL   1   4  23   1   0   ...    1.0  1.0
# 4  anderla02    1985      1    PHI   NL   3   3  57   0   0   ...    1.0  3.0
#
#    BK     BFP    GF    R  SH  SF  GIDP  salary
# 0   0   370.0  26.0   35 NaN NaN   NaN  170000
# 1   0   246.0  21.0   27 NaN NaN   NaN  147500
# 2   0  1090.0   0.0  105 NaN NaN   NaN  875000
# 3   1   135.0  13.0   22 NaN NaN   NaN  750000
# 4   1   318.0  19.0   41 NaN NaN   NaN  250500
#
# [5 rows x 31 columns]

# %%
df.isnull().any()
# Out:
# playerID    False
# yearID      False
# stint       False
# teamID      False
# lgID        False
# W           False
# L           False
# G           False
# GS          False
# CG          False
# SHO         False
# SV          False
# IPouts      False
# H           False
# ER          False
# HR          False
# BB          False
# SO          False
# BAOpp        True
# ERA          True
# IBB         False
# WP          False
# HBP         False
# BK          False
# BFP         False
# GF          False
# R           False
# SH           True
# SF           True
# GIDP         True
# salary      False
# dtype: bool

# %%
g = sns.FacetGrid(df,size=3)
g = g.map(plt.scatter, "W", "salary")

# %% [markdown]
# # American
# g = sns.FacetGrid(df[df["lgID"].str.contains("AL")],col="yearID",hue="teamID",col_wrap=5,size=2.2)
# g = g.map(plt.scatter, "W", "salary")
# g.add_legend()

# %% [markdown]
# # National
# g = sns.FacetGrid(df[df["lgID"].str.contains("NL")],col="yearID",hue="teamID",col_wrap=5,size=2.2)
# g = g.map(plt.scatter, "W", "salary")
# g.add_legend()
